# %% [markdown]
# # MNESIS : a notebook that runs all of them

# %%
import datetime

# %%
# print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 01_MNESIS_boilerplate.ipynb
# pprint("🚀 Running: 01_MNESIS_boilerplate.ipynb")
# print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# running in debug mode with DEBUG = 8
# datetag = '2026-06-18'
# Using device: mps
# SNNtorch version 0.9.4

# %%
# pprint("🚀 Running: 05_MNESIS_parameters.ipynb")
# print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 05_MNESIS_parameters.ipynb
# print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# pprint("🚀 Running: 08_MNESIS_generative-model.ipynb")
# print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 08_MNESIS_generative-model.ipynb
# print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# pripprintnt("🚀 Running: 10_MNESIS_polychronous-chains.ipynb")
# print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 10_MNESIS_polychronous-chains.ipynb
# print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 11_MNESIS_learn-synthetic.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 11_MNESIS_learn-synthetic.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ==========================================
# 🚀 Running: 11_MNESIS_learn-synthetic.ipynb
# ==========================================
# ⏱️  START: 2026-06-20 10:37:40
# running in debug mode with DEBUG = 8
# datetag = '2026-06-18'
# Using device: mps
# SNNtorch version 0.9.4
# Spikes in one target 2.6,  in a SM window 0.8
# for a value opt.lif_beta=0.7, the time constant is 2.8 steps
# /Users/laurentperrinet/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages/snntorch/spikeplot.py:120: UserWarning: You passed a edgecolor/edgecolors ('none') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   return ax.scatter(*torch.where(data.cpu()), **kwargs)
# Target pattern generated with shape torch.Size([2, 128, 125]) and mean 1.563e-04
# Flipping 342.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 1.084e-02
# Flipping 298.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 9.469e-03
# Flipping 330.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 1.047e-02
# Flipping 314.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 9.906e-03
# Spikes in one target 2.6,  in a SM window 0.8
# for a value opt.lif_beta=0.7, the time constant is 2.8 steps
# Model file is locked: ../cached_data/2026-06-18_init.lock, passing.
# precision = 0.000	 recall = 0.000	 f1_score = 0.000
# Model file not found: ../cached_data/2026-06-18_vanilla.pth, training a new model.
# Train Epoch [000001/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000002/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000003/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000004/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000005/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000006/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000007/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000008/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000009/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000010/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000011/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000012/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000013/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000014/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000015/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000016/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000017/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000018/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000019/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000020/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000021/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000022/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000023/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000024/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000025/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000026/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000027/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000028/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000029/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000030/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000031/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000032/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# precision = 0.000	 recall = 0.000	 f1_score = 0.000
# ✅ END: 2026-06-20 10:39:00

# %%
pprint("🚀 Running: 20_MNESIS_scanning-parameters.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 20_MNESIS_scanning-parameters.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ==============================================
# 🚀 Running: 20_MNESIS_scanning-parameters.ipynb
# ==============================================
# ⏱️  START: 2026-06-20 10:39:00
# running in debug mode with DEBUG = 8
# datetag = '2026-06-18'
# Using device: mps
# SNNtorch version 0.9.4
# Spikes in one target 2.6,  in a SM window 0.8
# for a value opt.lif_beta=0.7, the time constant is 2.8 steps
# /Users/laurentperrinet/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages/snntorch/spikeplot.py:120: UserWarning: You passed a edgecolor/edgecolors ('none') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   return ax.scatter(*torch.where(data.cpu()), **kwargs)
# Target pattern generated with shape torch.Size([2, 128, 125]) and mean 1.563e-04
# Flipping 342.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 1.084e-02
# Flipping 298.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 9.469e-03
# Flipping 330.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 1.047e-02
# Flipping 314.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 9.906e-03
# Spikes in one target 2.6,  in a SM window 0.8
# for a value opt.lif_beta=0.7, the time constant is 2.8 steps
# ================================================================================
# Scanning core network parameters to evaluate learning performance and robustness
# ================================================================================
# --------------------------------------------------
# scanning key='N_pattern'
# --------------------------------------------------
# |key='N_pattern':value=1.000e+00 	| already computed for i_cv=0, skipping.	| completed in 1.0m 39.4s |
# |key='N_pattern':value=1.000e+00 	| already computed for i_cv=1, skipping.	| completed in 1.0m 39.3s |
# --------------------------------------------------
# scanning key='N_time'
# --------------------------------------------------
# |key='N_time':value=1.000e+02 	| already computed for i_cv=0, skipping.	| completed in 1.0m 24.1s |
# |key='N_time':value=1.000e+02 	| already computed for i_cv=1, skipping.	| completed in 1.0m 27.9s |
# --------------------------------------------------
# scanning key='num_delay'
# --------------------------------------------------
# |key='num_delay':value=1.000e+00 	| already computed for i_cv=0, skipping.	| completed in 2.0m 1.5s |
# |key='num_delay':value=1.000e+00 	| already computed for i_cv=1, skipping.	| completed in 1.0m 45.5s |
# --------------------------------------------------
# scanning key='N_neuron'
# --------------------------------------------------
# |key='N_neuron':value=5.000e+01 	| already computed for i_cv=0, skipping.	| completed in 1.0m 23.2s |
# |key='N_neuron':value=5.000e+01 	| already computed for i_cv=1, skipping.	| completed in 1.0m 51.9s |
# --------------------------------------------------
# scanning key='p_A'
# --------------------------------------------------
# |key='p_A':value=2.000e-04 	| already computed for i_cv=0, skipping.	| completed in 1.0m 43.4s |
# |key='p_A':value=2.000e-04 	| already computed for i_cv=1, skipping.	| completed in 1.0m 42.6s |
# --------------------------------------------------
# scanning key='lif_threshold'
# --------------------------------------------------
# |key='lif_threshold':value=2.000e-02 	| already computed for i_cv=0, skipping.	| completed in 1.0m 26.5s |
# |key='lif_threshold':value=2.000e-02 	| already computed for i_cv=1, skipping.	| completed in 1.0m 42.0s |
# --------------------------------------------------
# scanning key='do_deconv'
# --------------------------------------------------
# |key='do_deconv':value=1.000e+00 	| already computed for i_cv=0, skipping.	| completed in 1.0m 53.0s |
# |key='do_deconv':value=1.000e+00 	| already computed for i_cv=1, skipping.	| completed in 1.0m 47.2s |
# |key='do_deconv':value=0.000e+00 	| already computed for i_cv=0, skipping.	| completed in 1.0m 44.4s |
# |key='do_deconv':value=0.000e+00 	| already computed for i_cv=1, skipping.	| completed in 1.0m 40.9s |
# --------------------------------------------------
# scanning key='do_pinv'
# --------------------------------------------------
# |key='do_pinv':value=1.000e+00 	| already computed for i_cv=0, skipping.	| completed in 1.0m 17.9s |
# |key='do_pinv':value=1.000e+00 	| already computed for i_cv=1, skipping.	| completed in 1.0m 10.7s |
# |key='do_pinv':value=0.000e+00 	| already computed for i_cv=0, skipping.	| completed in 1.0m 6.9s |
# |key='do_pinv':value=0.000e+00 	| already computed for i_cv=1, skipping.	| completed in 1.0m 6.6s |
# --------------------------------------------------
# scanning key='N_pattern'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-06-18_scan_N_pattern.json')...
#    N_pattern  i_cv  loss       time
# 0          1     0     0  99.384351
# 1          1     1     1  99.262227
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# --------------------------------------------------
# scanning key='N_time'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-06-18_scan_N_time.json')...
#    N_time  i_cv  loss       time
# 0     100     0     1  84.112445
# 1     100     1     1  87.943945
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# --------------------------------------------------
# scanning key='num_delay'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-06-18_scan_num_delay.json')...
#    num_delay  i_cv  loss        time
# 0          1     0     1  121.486662
# 1          1     1     1  105.472978
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# --------------------------------------------------
# scanning key='N_neuron'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-06-18_scan_N_neuron.json')...
#    N_neuron  i_cv  loss        time
# 0        50     0     1   83.179018
# 1        50     1     1  111.906598
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# --------------------------------------------------
# scanning key='p_A'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-06-18_scan_p_A.json')...
#       p_A  i_cv      loss        time
# 0  0.0002     0  1.000000  103.382124
# 1  0.0002     1  0.714286  102.612066
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# --------------------------------------------------
# scanning key='lif_threshold'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-06-18_scan_lif_threshold.json')...
#    lif_threshold  i_cv  loss        time
# 0           0.02     0   0.5   86.498712
# 1           0.02     1   0.6  102.039702
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# --------------------------------------------------
# scanning key='do_deconv'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-06-18_scan_do_deconv.json')...
#    do_deconv  i_cv      loss        time
# 0       True     0  0.000000  113.012231
# 1       True     1  0.333333  107.197843
# 2      False     0  0.333333  104.405203
# 3      False     1  1.000000  100.896937
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# --------------------------------------------------
# scanning key='do_pinv'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-06-18_scan_do_pinv.json')...
#    do_pinv  i_cv  loss       time
# 0     True     0     0  77.901157
# 1     True     1     1  70.709633
# 2    False     0     1  66.880034
# 3    False     1     1  66.622374
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# ==================================================================================
# Scanning stimulus-generation parameters to measure sensitivity to input statistics
# ==================================================================================
# --------------------------------------------------
# scanning key='p_flip'
# --------------------------------------------------
# |key='p_flip':value=1.000e-05 	| already computed for i_cv=0, skipping.	| completed in 1.0m 50.6s |
# |key='p_flip':value=1.000e-05 	| already computed for i_cv=1, skipping.	| completed in 3.0m 39.8s |
# --------------------------------------------------
# scanning key='p_flip'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-06-18_scan_p_flip.json')...
#     p_flip  i_cv      loss        time
# 0  0.00001     0  0.333333  110.566350
# 1  0.00001     1  1.000000  219.782161
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# ✅ END: 2026-06-20 10:39:00

# %%
pprint("🚀 Running: 13_MNESIS_testing-inference.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 13_MNESIS_testing-inference.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ============================================
# 🚀 Running: 13_MNESIS_testing-inference.ipynb
# ============================================
# ⏱️  START: 2026-06-20 10:39:00
# running in debug mode with DEBUG = 8
# datetag = '2026-06-18'
# Using device: mps
# SNNtorch version 0.9.4
# Spikes in one target 2.6,  in a SM window 0.8
# for a value opt.lif_beta=0.7, the time constant is 2.8 steps
# /Users/laurentperrinet/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages/snntorch/spikeplot.py:120: UserWarning: You passed a edgecolor/edgecolors ('none') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   return ax.scatter(*torch.where(data.cpu()), **kwargs)
# Target pattern generated with shape torch.Size([2, 128, 125]) and mean 1.563e-04
# Flipping 342.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 1.084e-02
# Flipping 298.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 9.469e-03
# Flipping 330.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 1.047e-02
# Flipping 314.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 9.906e-03
# Spikes in one target 2.6,  in a SM window 0.8
# for a value opt.lif_beta=0.7, the time constant is 2.8 steps
# Model weights loaded from ../cached_data/2026-06-18_init.pth
# precision = 1.000	 recall = 0.333	 f1_score = 0.500
# Model weights loaded from ../cached_data/2026-06-18_vanilla.pth
# precision = 0.000	 recall = 0.000	 f1_score = 0.000
# Model weights loaded from ../cached_data/2026-06-18_vanilla.pth
# Score file not found: ../cached_data/2026-06-18_vanilla.pth, evaluating the score.
# torch.Size([128, 1050])
# /var/folders/3s/q2x8bxzj43g4rdvb2wjt67640000gq/T/ipykernel_28646/2752886546.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc='lower right')
# /Users/laurentperrinet/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages/matplotlib/animation.py:1774: UserWarning: Can not start iterating the frames for the initial draw. This can be caused by passing in a 0 length sequence for *frames*.
#
# If you passed *frames* as a generator it may be exhausted due to a previous display or save.
#   warnings.warn(
# ✅ END: 2026-06-20 10:39:02

# %%
pprint("🚀 Running: 14_MNESIS_testing-noise.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 14_MNESIS_testing-noise.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ========================================
# 🚀 Running: 14_MNESIS_testing-noise.ipynb
# ========================================
# ⏱️  START: 2026-06-20 10:39:02
# running in debug mode with DEBUG = 8
# datetag = '2026-06-18'
# Using device: mps
# SNNtorch version 0.9.4
# Spikes in one target 2.6,  in a SM window 0.8
# for a value opt.lif_beta=0.7, the time constant is 2.8 steps
# Target pattern generated with shape torch.Size([2, 128, 125]) and mean 1.563e-04
# Flipping 342.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 1.084e-02
# Flipping 298.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 9.469e-03
# Flipping 330.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 1.047e-02
# Flipping 314.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 9.906e-03
# Spikes in one target 2.6,  in a SM window 0.8
# for a value opt.lif_beta=0.7, the time constant is 2.8 steps
# Model weights loaded from ../cached_data/2026-06-18_init.pth
# precision = 1.000	 recall = 0.333	 f1_score = 0.500
# Model weights loaded from ../cached_data/2026-06-18_vanilla.pth
# precision = 0.000	 recall = 0.000	 f1_score = 0.000
# Model weights loaded from ../cached_data/2026-06-18_vanilla.pth
# precision = 0.000	 recall = 0.000	 f1_score = 0.000
# Score file not found: ../cached_data/2026-06-18_vanilla.pth, evaluating the score.
# 100%|██████████| 3/3 [00:00<00:00,  8.74it/s]
# ✅ END: 2026-06-20 10:39:04

# %%
pprint("🚀 Running: 15_MNESIS_testing-trigger-duration.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 15_MNESIS_testing-trigger-duration.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ===================================================
# 🚀 Running: 15_MNESIS_testing-trigger-duration.ipynb
# ===================================================
# ⏱️  START: 2026-06-20 10:39:04
# running in debug mode with DEBUG = 8
# datetag = '2026-06-18'
# Using device: mps
# SNNtorch version 0.9.4
# Spikes in one target 2.6,  in a SM window 0.8
# for a value opt.lif_beta=0.7, the time constant is 2.8 steps
# Target pattern generated with shape torch.Size([2, 128, 125]) and mean 1.563e-04
# Flipping 342.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 1.084e-02
# Flipping 298.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 9.469e-03
# Flipping 330.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 1.047e-02
# Flipping 314.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 9.906e-03
# Spikes in one target 2.6,  in a SM window 0.8
# for a value opt.lif_beta=0.7, the time constant is 2.8 steps
# Model weights loaded from ../cached_data/2026-06-18_init.pth
# precision = 1.000	 recall = 0.333	 f1_score = 0.500
# Model weights loaded from ../cached_data/2026-06-18_vanilla.pth
# precision = 0.000	 recall = 0.000	 f1_score = 0.000
# Model weights loaded from ../cached_data/2026-06-18_vanilla.pth
# precision = 0.000	 recall = 0.000	 f1_score = 0.000
# Score file not found: ../cached_data/2026-06-18_vanilla.pth, evaluating the score.
# ✅ END: 2026-06-20 10:39:10

# %%
pprint("🚀 Running: 16_MNESIS_testing-trigger-fraction.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 16_MNESIS_testing-trigger-fraction.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ===================================================
# 🚀 Running: 16_MNESIS_testing-trigger-fraction.ipynb
# ===================================================
# ⏱️  START: 2026-06-20 10:39:10
# running in debug mode with DEBUG = 8
# datetag = '2026-06-18'
# Using device: mps
# SNNtorch version 0.9.4
# Spikes in one target 2.6,  in a SM window 0.8
# for a value opt.lif_beta=0.7, the time constant is 2.8 steps
# Target pattern generated with shape torch.Size([2, 128, 125]) and mean 1.563e-04
# Flipping 342.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 1.084e-02
# Flipping 298.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 9.469e-03
# Flipping 330.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 1.047e-02
# Flipping 314.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 9.906e-03
# Spikes in one target 2.6,  in a SM window 0.8
# for a value opt.lif_beta=0.7, the time constant is 2.8 steps
# Model weights loaded from ../cached_data/2026-06-18_init.pth
# precision = 1.000	 recall = 0.333	 f1_score = 0.500
# Model weights loaded from ../cached_data/2026-06-18_vanilla.pth
# precision = 0.000	 recall = 0.000	 f1_score = 0.000
# Model weights loaded from ../cached_data/2026-06-18_vanilla.pth
# precision = 0.000	 recall = 0.000	 f1_score = 0.000
# Score file not found: ../cached_data/2026-06-18_vanilla.pth, evaluating the score.
# ✅ END: 2026-06-20 10:39:11

# %%
pprint("🚀 Running: 25_MNESIS_optuna.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 25_MNESIS_optuna.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# =================================
# 🚀 Running: 25_MNESIS_optuna.ipynb
# =================================
# ⏱️  START: 2026-06-20 10:39:11
# running in debug mode with DEBUG = 8
# datetag = '2026-06-18'
# Using device: mps
# SNNtorch version 0.9.4
# Spikes in one target 2.6,  in a SM window 0.8
# for a value opt.lif_beta=0.7, the time constant is 2.8 steps
# Target pattern generated with shape torch.Size([2, 128, 125]) and mean 1.563e-04
# Flipping 342.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 1.084e-02
# Flipping 298.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 9.469e-03
# Flipping 330.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 1.047e-02
# Flipping 314.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 9.906e-03
# ===================================================================================================
# Optimizing learning parameters with Optuna: running hyperparameter search and analyzing best trials
# ===================================================================================================
# ls: ../cached_data/2026-06-18_optuna.sqlite3: No such file or directory
# Optuna file not found or unlocked: ../cached_data/2026-06-18_optuna.sqlite3, starting optimization.
# Starting optimization on 3 trials with 0 existing trials.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
pprint("🚀 Running: 30_MNESIS_learn-periodic.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 30_MNESIS_learn-periodic.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 32_MNESIS_learn-travelling-waves.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 32_MNESIS_learn-travelling-waves.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 34_MNESIS_learn-Lorenz-attractor.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 34_MNESIS_learn-Lorenz-attractor.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# pprint("🚀 Running: 40_MNESIS_learn-SHD.ipynb")
# print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 40_MNESIS_learn-SHD.ipynb
# print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("✅ All MNESIS notebooks executed successfully!")
