# %% [markdown]
# # MNESIS : a notebook that runs all of them

# %%
import datetime

# %%
# print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 01_MNESIS_boilerplate.ipynb
# pprint("🚀 Running: 01_MNESIS_boilerplate.ipynb")
# print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# datetag = '2026-06-23'
# Using device: mps
# SNNtorch version 0.9.4

# %%
# pprint("🚀 Running: 05_MNESIS_parameters.ipynb")
# print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 05_MNESIS_parameters.ipynb
# print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# pprint("🚀 Running: 08_MNESIS_generative-model.ipynb")
# print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 08_MNESIS_generative-model.ipynb
# print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# pripprintnt("🚀 Running: 10_MNESIS_polychronous-chains.ipynb")
# print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 10_MNESIS_polychronous-chains.ipynb
# print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 11_MNESIS_learn-synthetic.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 11_MNESIS_learn-synthetic.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ==========================================
# 🚀 Running: 11_MNESIS_learn-synthetic.ipynb
# ==========================================
# ⏱️  START: 2026-07-11 11:55:43
# datetag = '2026-06-23'
# Using device: mps
# SNNtorch version 0.9.4
# Spikes in one target 163.8,  in a SM window 6.7
# for a value opt.lif_beta=0.8, the time constant is 4.5 steps
# Target pattern generated with shape torch.Size([16, 1024, 1000]) and mean 1.605e-04
# Spikes in one target 163.8,  in a SM window 6.7
# for a value opt.lif_beta=0.8, the time constant is 4.5 steps
# Model weights loaded from ../cached_data/2026-06-23_init.pth
# precision = 0.845	 recall = 0.927	 f1_score = 0.884
# Saving as ../figures/pattern.pdf
# Saving as ../figures/pattern.png
# Saving as ../figures/pattern.svg
# Saving as ../figures/target_init.pdf
# Saving as ../figures/target_init.png
# Saving as ../figures/target_init.svg
# Model weights loaded from ../cached_data/2026-06-23_vanilla.pth
# precision = 0.870	 recall = 0.927	 f1_score = 0.898
# Saving as ../figures/target.pdf
# Saving as ../figures/target.png
# Saving as ../figures/target.svg
# ✅ END: 2026-07-11 11:56:08

# %%
pprint("🚀 Running: 13_MNESIS_testing-inference.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 13_MNESIS_testing-inference.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ============================================
# 🚀 Running: 13_MNESIS_testing-inference.ipynb
# ============================================
# ⏱️  START: 2026-07-11 11:56:08
# datetag = '2026-06-23'
# Using device: mps
# SNNtorch version 0.9.4
# Spikes in one target 163.8,  in a SM window 6.7
# for a value opt.lif_beta=0.8, the time constant is 4.5 steps
# Target pattern generated with shape torch.Size([16, 1024, 1000]) and mean 1.605e-04
# Spikes in one target 163.8,  in a SM window 6.7
# for a value opt.lif_beta=0.8, the time constant is 4.5 steps
# Model weights loaded from ../cached_data/2026-06-23_init.pth
# precision = 0.845	 recall = 0.927	 f1_score = 0.884
# Saving as ../figures/pattern.pdf
# Saving as ../figures/pattern.png
# Saving as ../figures/pattern.svg
# Saving as ../figures/target_init.pdf
# Saving as ../figures/target_init.png
# Saving as ../figures/target_init.svg
# Model weights loaded from ../cached_data/2026-06-23_vanilla.pth
# precision = 0.870	 recall = 0.927	 f1_score = 0.898
# Saving as ../figures/target.pdf
# Saving as ../figures/target.png
# Saving as ../figures/target.svg
# Model weights loaded from ../cached_data/2026-06-23_vanilla.pth
# Score weights loaded from ../cached_data/2026-06-23_vanilla.pth
# Saving as ../figures/retrieval.pdf
# Saving as ../figures/retrieval.png
# Saving as ../figures/retrieval.svg
# /var/folders/3s/q2x8bxzj43g4rdvb2wjt67640000gq/T/ipykernel_73178/2752886546.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc='lower right')
# ✅ END: 2026-07-11 11:56:39

# %%
pprint("🚀 Running: 14_MNESIS_testing-noise.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 14_MNESIS_testing-noise.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ========================================
# 🚀 Running: 14_MNESIS_testing-noise.ipynb
# ========================================
# ⏱️  START: 2026-07-11 13:41:15
# datetag = '2026-06-23'
# Using device: mps
# SNNtorch version 0.9.4
# Spikes in one target 163.8,  in a SM window 6.7
# for a value opt.lif_beta=0.8, the time constant is 4.5 steps
# Target pattern generated with shape torch.Size([16, 1024, 1000]) and mean 1.605e-04
# Spikes in one target 163.8,  in a SM window 6.7
# for a value opt.lif_beta=0.8, the time constant is 4.5 steps
# Model weights loaded from ../cached_data/2026-06-23_init.pth
# precision = 0.845	 recall = 0.927	 f1_score = 0.884
# Saving as ../figures/pattern.pdf
# Saving as ../figures/pattern.png
# Saving as ../figures/pattern.svg
# Saving as ../figures/target_init.pdf
# Saving as ../figures/target_init.png
# Saving as ../figures/target_init.svg
# Model weights loaded from ../cached_data/2026-06-23_vanilla.pth
# precision = 0.870	 recall = 0.927	 f1_score = 0.898
# Saving as ../figures/target.pdf
# Saving as ../figures/target.png
# Saving as ../figures/target.svg
# Model weights loaded from ../cached_data/2026-06-23_vanilla.pth
# precision = 0.833	 recall = 0.758	 f1_score = 0.793
# Saving as ../figures/p_flip_target.pdf
# Saving as ../figures/p_flip_target.png
# Saving as ../figures/p_flip_target.svg
# Score weights loaded from ../cached_data/2026-06-23_vanilla.pth
# Saving as ../figures/p_flip_score.pdf
# Saving as ../figures/p_flip_score.png
# Saving as ../figures/p_flip_score.svg
# ✅ END: 2026-07-11 13:41:36

# %%
pprint("🚀 Running: 15_MNESIS_testing-trigger-duration.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 15_MNESIS_testing-trigger-duration.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ===================================================
# 🚀 Running: 15_MNESIS_testing-trigger-duration.ipynb
# ===================================================
# ⏱️  START: 2026-07-11 13:41:36
# datetag = '2026-06-23'
# Using device: mps
# SNNtorch version 0.9.4
# Spikes in one target 163.8,  in a SM window 6.7
# for a value opt.lif_beta=0.8, the time constant is 4.5 steps
# Target pattern generated with shape torch.Size([16, 1024, 1000]) and mean 1.605e-04
# Spikes in one target 163.8,  in a SM window 6.7
# for a value opt.lif_beta=0.8, the time constant is 4.5 steps
# Model weights loaded from ../cached_data/2026-06-23_init.pth
# precision = 0.845	 recall = 0.927	 f1_score = 0.884
# Saving as ../figures/pattern.pdf
# Saving as ../figures/pattern.png
# Saving as ../figures/pattern.svg
# Saving as ../figures/target_init.pdf
# Saving as ../figures/target_init.png
# Saving as ../figures/target_init.svg
# Model weights loaded from ../cached_data/2026-06-23_vanilla.pth
# precision = 0.870	 recall = 0.927	 f1_score = 0.898
# Saving as ../figures/target.pdf
# Saving as ../figures/target.png
# Saving as ../figures/target.svg
# Model weights loaded from ../cached_data/2026-06-23_vanilla.pth
# precision = 0.746	 recall = 0.622	 f1_score = 0.678
# Saving as ../figures/trigger_time.pdf
# Saving as ../figures/trigger_time.png
# Saving as ../figures/trigger_time.svg
# Score weights loaded from ../cached_data/2026-06-23_vanilla.pth
# Saving as ../figures/trigger_time_score.pdf
# Saving as ../figures/trigger_time_score.png
# Saving as ../figures/trigger_time_score.svg
# ✅ END: 2026-07-11 13:41:56

# %%
pprint("🚀 Running: 16_MNESIS_testing-trigger-fraction.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 16_MNESIS_testing-trigger-fraction.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ===================================================
# 🚀 Running: 16_MNESIS_testing-trigger-fraction.ipynb
# ===================================================
# ⏱️  START: 2026-07-11 13:41:56
# datetag = '2026-06-23'
# Using device: mps
# SNNtorch version 0.9.4
# Spikes in one target 163.8,  in a SM window 6.7
# for a value opt.lif_beta=0.8, the time constant is 4.5 steps
# Target pattern generated with shape torch.Size([16, 1024, 1000]) and mean 1.605e-04
# Spikes in one target 163.8,  in a SM window 6.7
# for a value opt.lif_beta=0.8, the time constant is 4.5 steps
# Model weights loaded from ../cached_data/2026-06-23_init.pth
# precision = 0.845	 recall = 0.927	 f1_score = 0.884
# Saving as ../figures/pattern.pdf
# Saving as ../figures/pattern.png
# Saving as ../figures/pattern.svg
# Saving as ../figures/target_init.pdf
# Saving as ../figures/target_init.png
# Saving as ../figures/target_init.svg
# Model weights loaded from ../cached_data/2026-06-23_vanilla.pth
# precision = 0.870	 recall = 0.927	 f1_score = 0.898
# Saving as ../figures/target.pdf
# Saving as ../figures/target.png
# Saving as ../figures/target.svg
# Model weights loaded from ../cached_data/2026-06-23_vanilla.pth
# precision = 0.841	 recall = 0.894	 f1_score = 0.866
# Saving as ../figures/fraction_target.pdf
# Saving as ../figures/fraction_target.png
# Saving as ../figures/fraction_target.svg
# Score weights loaded from ../cached_data/2026-06-23_vanilla.pth
# Saving as ../figures/fraction_target_score.pdf
# Saving as ../figures/fraction_target_score.png
# Saving as ../figures/fraction_target_score.svg
# ✅ END: 2026-07-11 13:42:15

# %%
pprint("🚀 Running: 20_MNESIS_scanning-parameters.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 20_MNESIS_scanning-parameters.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 25_MNESIS_optuna.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 25_MNESIS_optuna.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# =================================
# 🚀 Running: 25_MNESIS_optuna.ipynb
# =================================
# ⏱️  START: 2026-07-11 13:42:15
# datetag = '2026-06-23'
# Using device: mps
# SNNtorch version 0.9.4
# Spikes in one target 163.8,  in a SM window 6.7
# for a value opt.lif_beta=0.8, the time constant is 4.5 steps
# Target pattern generated with shape torch.Size([16, 1024, 1000]) and mean 1.605e-04
# ===================================================================================================
# Optimizing learning parameters with Optuna: running hyperparameter search and analyzing best trials
# ===================================================================================================
# -rw-r-----@ 1 laurentperrinet  staff  495616 10 juil. 22:37 ../cached_data/2026-06-23_optuna.sqlite3
# Optuna file not found or unlocked: ../cached_data/2026-06-23_optuna.sqlite3, starting optimization.
# So far, Best params:  {'do_deconv': True, 'do_pinv': True, 'lif_beta': 0.9851270668097004, 'alpha_surrogate': 15.454478512981101, 'base_lr': 0.022287943287326566, 'final_lr': 0.00045211394882154225, 'delta1': 0.02851753272977885, 'delta2': 2.1995472956169266e-05, 'weight_decay': 5.320607157060542e-10, 'dropout': 0.1644417209098904, 'lif_threshold': 0.7259481686312336}, Best value:  0.09947234392166138
# Starting optimization on 0 trials with 200 existing trials.
# number of trials in study: 200
# -.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.
# Best params:  {'do_deconv': True, 'do_pinv': True, 'lif_beta': 0.9851270668097004, 'alpha_surrogate': 15.454478512981101, 'base_lr': 0.022287943287326566, 'final_lr': 0.00045211394882154225, 'delta1': 0.02851753272977885, 'delta2': 2.1995472956169266e-05, 'weight_decay': 5.320607157060542e-10, 'dropout': 0.1644417209098904, 'lif_threshold': 0.7259481686312336}
# Best value:  0.09947234392166138
# ============================================================
# OPTUNA STUDY ANALYSIS
# ============================================================
#
# [1] PARAMETER IMPORTANCE RANKING:
# lif_threshold                 : 0.611
# do_pinv                       : 0.269
# delta2                        : 0.044
# lif_beta                      : 0.024
# final_lr                      : 0.023
# do_deconv                     : 0.014
# alpha_surrogate               : 0.008
# base_lr                       : 0.003
# delta1                        : 0.002
# dropout                       : 0.002
# weight_decay                  : 0.000
#
# [2] BEST VALUES WITH CONFIDENCE INTERVALS:
#
# Best Objective Value: 0.09947
#
# Estimated Confidence Intervals (Top 10% Trials):
# do_deconv	: Best=True,	 Most Common=True, True: 11/19 (57.9%)
# do_pinv	: Best=True,	 Most Common=True, True: 18/19 (94.7%)
# lif_beta	: Best=9.851271e-01,	 Median=7.996e-01, 90% CI=[3.099e-01, 9.731e-01]
# alpha_surrogate	: Best=1.545448e+01,	 Median=1.329e+01, 90% CI=[5.703e+00, 4.893e+01]
# base_lr	: Best=2.228794e-02,	 Median=1.792e-02, 90% CI=[1.430e-02, 6.029e-02]
# final_lr	: Best=4.521139e-04,	 Median=4.991e-04, 90% CI=[2.965e-04, 1.096e-03]
# delta1	: Best=2.851753e-02,	 Median=1.563e-02, 90% CI=[7.900e-03, 3.304e-02]
# delta2	: Best=2.199547e-05,	 Median=2.686e-05, 90% CI=[1.461e-05, 1.068e-04]
# weight_decay	: Best=5.320607e-10,	 Median=5.123e-10, 90% CI=[2.840e-10, 1.442e-09]
# dropout	: Best=1.644417e-01,	 Median=2.719e-01, 90% CI=[1.561e-02, 4.746e-01]
# lif_threshold	: Best=7.259482e-01,	 Median=1.315e+00, 90% CI=[9.971e-01, 1.783e+00]
#
# ============================================================
# /Users/laurentperrinet/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages/statsmodels/nonparametric/smoothers_lowess.py:226: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),
# ✅ END: 2026-07-11 13:42:21

# %%
pprint("🚀 Running: 30_MNESIS_learn-periodic.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 30_MNESIS_learn-periodic.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# =========================================
# 🚀 Running: 30_MNESIS_learn-periodic.ipynb
# =========================================
# ⏱️  START: 2026-07-11 13:42:21
# datetag = '2026-06-23'
# Using device: mps
# SNNtorch version 0.9.4
# Spikes in one target 163.8,  in a SM window 6.7
# for a value opt.lif_beta=0.8, the time constant is 4.5 steps
# Target pattern generated with shape torch.Size([16, 1024, 1000]) and mean 1.605e-04
# Model weights loaded from ../cached_data/2026-06-23_periodic.pth
# precision = 0.848	 recall = 0.945	 f1_score = 0.894
# precision = 0.870	 recall = 0.873	 f1_score = 0.871
# precision = 0.581	 recall = 0.621	 f1_score = 0.600
# Score weights loaded from ../cached_data/2026-06-23_periodic.pth
# ✅ END: 2026-07-11 13:48:26

# %%
pprint("🚀 Running: 32_MNESIS_learn-travelling-waves.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 32_MNESIS_learn-travelling-waves.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 34_MNESIS_learn-Lorenz-attractor.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 34_MNESIS_learn-Lorenz-attractor.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# pprint("🚀 Running: 40_MNESIS_learn-SHD.ipynb")
# print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 40_MNESIS_learn-SHD.ipynb
# print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("✅ All MNESIS notebooks executed successfully!")
# Out:
# =============================================
# ✅ All MNESIS notebooks executed successfully!
# =============================================
