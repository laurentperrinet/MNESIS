# %% [markdown]
# # MNESIS : a notebook that runs all of them

# %%
import datetime

# %%
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 01_MNESIS_boilerplate.ipynb
pprint("🚀 Running: 01_MNESIS_boilerplate.ipynb")
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ⏱️  START: 2026-07-29 17:44:35
# datetag = '2026-07-11'
# Using device: mps
# SNNtorch version 0.9.4
# ======================================
# 🚀 Running: 01_MNESIS_boilerplate.ipynb
# ======================================
# ✅ END: 2026-07-29 17:44:38

# %%
pprint("🚀 Running: 05_MNESIS_parameters.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 05_MNESIS_parameters.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# =====================================
# 🚀 Running: 05_MNESIS_parameters.ipynb
# =====================================
# ⏱️  START: 2026-07-29 17:44:38
# Spikes in one target 163.8,  in a SM window 6.7
# for a value opt.lif_beta=0.8, the time constant is 4.5 steps
# ✅ END: 2026-07-29 17:44:38

# %%
pprint("🚀 Running: 08_MNESIS_generative-model.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 08_MNESIS_generative-model.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ===========================================
# 🚀 Running: 08_MNESIS_generative-model.ipynb
# ===========================================
# ⏱️  START: 2026-07-29 17:44:38
# Description: A stochastic pattern generator
# Target pattern generated with shape torch.Size([16, 1024, 1000]) and mean 1.605e-04
# ✅ END: 2026-07-29 17:44:38

# %%
pprint("🚀 Running: 10_MNESIS_polychronous-chains.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 10_MNESIS_polychronous-chains.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ==============================================
# 🚀 Running: 10_MNESIS_polychronous-chains.ipynb
# ==============================================
# ⏱️  START: 2026-07-29 17:44:38
# ✅ END: 2026-07-29 17:44:38

# %%
pprint("🚀 Running: 11_MNESIS_learn-synthetic.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 11_MNESIS_learn-synthetic.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ==========================================
# 🚀 Running: 11_MNESIS_learn-synthetic.ipynb
# ==========================================
# ⏱️  START: 2026-07-29 17:44:38
# for a value opt.lif_beta=0.8, the time constant is 4.5 steps
# Model weights loaded from ../cached_data/2026-07-11_init.pth
# precision = 0.904	 recall = 0.922	 f1_score = 0.913
# Saving as ../figures/pattern.pdf
# Saving as ../figures/pattern.png
# Saving as ../figures/pattern.svg
# Saving as ../figures/target_init.pdf
# Saving as ../figures/target_init.png
# Saving as ../figures/target_init.svg
# Model weights loaded from ../cached_data/2026-07-11_vanilla.pth
# precision = 0.912	 recall = 0.884	 f1_score = 0.898
# Saving as ../figures/target.pdf
# Saving as ../figures/target.png
# Saving as ../figures/target.svg
# ✅ END: 2026-07-29 17:44:41

# %%
pprint("🚀 Running: 13_MNESIS_testing-inference.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 13_MNESIS_testing-inference.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ============================================
# 🚀 Running: 13_MNESIS_testing-inference.ipynb
# ============================================
# ⏱️  START: 2026-07-29 17:44:41
# Model weights loaded from ../cached_data/2026-07-11_vanilla.pth
# Score weights loaded from ../cached_data/2026-07-11_vanilla.pth
# Saving as ../figures/retrieval.pdf
# Saving as ../figures/retrieval.png
# Saving as ../figures/retrieval.svg
# /private/tmp/ipykernel_11709/2752886546.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc='lower right')
# ✅ END: 2026-07-29 17:44:46

# %%
pprint("🚀 Running: 14_MNESIS_testing-noise.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 14_MNESIS_testing-noise.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ========================================
# 🚀 Running: 14_MNESIS_testing-noise.ipynb
# ========================================
# ⏱️  START: 2026-07-29 17:44:46
# Model weights loaded from ../cached_data/2026-07-11_vanilla.pth
# precision = 0.888	 recall = 0.476	 f1_score = 0.619
# Saving as ../figures/p_flip_target.pdf
# Saving as ../figures/p_flip_target.png
# Saving as ../figures/p_flip_target.svg
# Score weights loaded from ../cached_data/2026-07-11_vanilla.pth
# Saving as ../figures/p_flip_score.pdf
# Saving as ../figures/p_flip_score.png
# Saving as ../figures/p_flip_score.svg
# ✅ END: 2026-07-29 17:44:47

# %%
pprint("🚀 Running: 15_MNESIS_testing-trigger-duration.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 15_MNESIS_testing-trigger-duration.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ===================================================
# 🚀 Running: 15_MNESIS_testing-trigger-duration.ipynb
# ===================================================
# ⏱️  START: 2026-07-29 17:44:47
# Model weights loaded from ../cached_data/2026-07-11_vanilla.pth
# precision = 0.631	 recall = 0.310	 f1_score = 0.416
# Saving as ../figures/trigger_time.pdf
# Saving as ../figures/trigger_time.png
# Saving as ../figures/trigger_time.svg
# Score weights loaded from ../cached_data/2026-07-11_vanilla.pth
# Saving as ../figures/trigger_time_score.pdf
# Saving as ../figures/trigger_time_score.png
# Saving as ../figures/trigger_time_score.svg
# ✅ END: 2026-07-29 17:44:48

# %%
pprint("🚀 Running: 16_MNESIS_testing-trigger-fraction.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 16_MNESIS_testing-trigger-fraction.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ===================================================
# 🚀 Running: 16_MNESIS_testing-trigger-fraction.ipynb
# ===================================================
# ⏱️  START: 2026-07-29 17:44:48
# Model weights loaded from ../cached_data/2026-07-11_vanilla.pth
# precision = 0.837	 recall = 0.466	 f1_score = 0.599
# Saving as ../figures/fraction_target.pdf
# Saving as ../figures/fraction_target.png
# Saving as ../figures/fraction_target.svg
# Score weights loaded from ../cached_data/2026-07-11_vanilla.pth
# Saving as ../figures/fraction_target_score.pdf
# Saving as ../figures/fraction_target_score.png
# Saving as ../figures/fraction_target_score.svg
# ✅ END: 2026-07-29 17:44:49

# %%
pprint("🚀 Running: 20_MNESIS_scanning-parameters.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 20_MNESIS_scanning-parameters.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ==============================================
# 🚀 Running: 20_MNESIS_scanning-parameters.ipynb
# ==============================================
# ⏱️  START: 2026-07-29 17:44:49
# Spikes in one target 163.8,  in a SM window 6.7
# for a value opt.lif_beta=0.8, the time constant is 4.5 steps
# ================================================================================
# Scanning core network parameters to evaluate learning performance and robustness
# ================================================================================
# --------------------------------------------------
# scanning key='N_pattern'
# --------------------------------------------------
# |key='N_pattern':value=1.000e+00 	 | already computed for i_cv=0, skipping.	| completed in 36.0m 43.4s |
# |key='N_pattern':value=1.000e+00 	 | already computed for i_cv=1, skipping.	| completed in 35.0m 20.9s |
# |key='N_pattern':value=3.000e+00 	 | already computed for i_cv=0, skipping.	| completed in 36.0m 30.4s |
# |key='N_pattern':value=3.000e+00 	 | already computed for i_cv=1, skipping.	| completed in 35.0m 29.5s |
# |key='N_pattern':value=5.000e+00 	 | already computed for i_cv=0, skipping.	| completed in 38.0m 54.9s |
# |key='N_pattern':value=5.000e+00 	 | already computed for i_cv=1, skipping.	| completed in 36.0m 5.4s |
# |key='N_pattern':value=7.000e+00 	 | already computed for i_cv=0, skipping.	| completed in 38.0m 9.4s |
# |key='N_pattern':value=7.000e+00 	 | already computed for i_cv=1, skipping.	| completed in 39.0m 19.8s |
# |key='N_pattern':value=9.000e+00 	 | already computed for i_cv=0, skipping.	| completed in 41.0m 6.6s |
# |key='N_pattern':value=9.000e+00 	 | already computed for i_cv=1, skipping.	| completed in 44.0m 8.7s |
# |key='N_pattern':value=1.100e+01 	 | already computed for i_cv=0, skipping.	| completed in 44.0m 25.0s |
# |key='N_pattern':value=1.100e+01 	 | already computed for i_cv=1, skipping.	| completed in 40.0m 48.3s |
# |key='N_pattern':value=1.300e+01 	 | already computed for i_cv=0, skipping.	| completed in 46.0m 4.1s |
# |key='N_pattern':value=1.300e+01 	 | already computed for i_cv=1, skipping.	| completed in 50.0m 55.6s |
# |key='N_pattern':value=1.500e+01 	 | already computed for i_cv=0, skipping.	| completed in 39.0m 52.2s |
# |key='N_pattern':value=1.500e+01 	 | already computed for i_cv=1, skipping.	| completed in 55.0m 18.0s |
# |key='N_pattern':value=1.700e+01 	 | already computed for i_cv=0, skipping.	| completed in 44.0m 38.4s |
# |key='N_pattern':value=1.700e+01 	 | already computed for i_cv=1, skipping.	| completed in 56.0m 48.7s |
# |key='N_pattern':value=1.900e+01 	 | already computed for i_cv=0, skipping.	| completed in 56.0m 35.3s |
# |key='N_pattern':value=1.900e+01 	 | already computed for i_cv=1, skipping.	| completed in 56.0m 1.9s |
# |key='N_pattern':value=2.100e+01 	 | already computed for i_cv=0, skipping.	| completed in 59.0m 33.7s |
# |key='N_pattern':value=2.100e+01 	 | already computed for i_cv=1, skipping.	| completed in 58.0m 21.0s |
# |key='N_pattern':value=2.300e+01 	 | already computed for i_cv=0, skipping.	| completed in 63.0m 26.3s |
# |key='N_pattern':value=2.300e+01 	 | already computed for i_cv=1, skipping.	| completed in 63.0m 11.4s |
# |key='N_pattern':value=2.600e+01 	 | already computed for i_cv=0, skipping.	| completed in 69.0m 42.9s |
# |key='N_pattern':value=2.600e+01 	 | already computed for i_cv=1, skipping.	| completed in 65.0m 5.5s |
# --------------------------------------------------
# scanning key='N_time'
# --------------------------------------------------
# --------------------------------------------------
# scanning key='num_delay'
# --------------------------------------------------
# |key='num_delay':value=1.000e+00 	 | already computed for i_cv=0, skipping.	| completed in 32.0m 14.5s |
# |key='num_delay':value=1.000e+00 	 | already computed for i_cv=1, skipping.	| completed in 31.0m 46.6s |
# |key='num_delay':value=5.000e+00 	 | already computed for i_cv=0, skipping.	| completed in 32.0m 15.3s |
# |key='num_delay':value=5.000e+00 	 | already computed for i_cv=1, skipping.	| completed in 32.0m 21.6s |
# |key='num_delay':value=1.000e+01 	 | already computed for i_cv=0, skipping.	| completed in 33.0m 5.1s |
# |key='num_delay':value=1.000e+01 	 | already computed for i_cv=1, skipping.	| completed in 32.0m 54.0s |
# |key='num_delay':value=1.500e+01 	 | already computed for i_cv=0, skipping.	| completed in 33.0m 59.2s |
# |key='num_delay':value=1.500e+01 	 | already computed for i_cv=1, skipping.	| completed in 33.0m 47.5s |
# |key='num_delay':value=2.000e+01 	 | already computed for i_cv=0, skipping.	| completed in 36.0m 8.2s |
# |key='num_delay':value=2.000e+01 	 | already computed for i_cv=1, skipping.	| completed in 36.0m 10.7s |
# |key='num_delay':value=2.500e+01 	 | already computed for i_cv=0, skipping.	| completed in 38.0m 40.0s |
# |key='num_delay':value=2.500e+01 	 | already computed for i_cv=1, skipping.	| completed in 38.0m 28.6s |
# |key='num_delay':value=3.000e+01 	 | already computed for i_cv=0, skipping.	| completed in 41.0m 11.6s |
# |key='num_delay':value=3.000e+01 	 | already computed for i_cv=1, skipping.	| completed in 41.0m 20.5s |
# |key='num_delay':value=3.500e+01 	 | already computed for i_cv=0, skipping.	| completed in 44.0m 8.4s |
# |key='num_delay':value=3.500e+01 	 | already computed for i_cv=1, skipping.	| completed in 43.0m 35.6s |
# |key='num_delay':value=4.000e+01 	 | already computed for i_cv=0, skipping.	| completed in 46.0m 53.1s |
# |key='num_delay':value=4.000e+01 	 | already computed for i_cv=1, skipping.	| completed in 47.0m 6.5s |
# |key='num_delay':value=4.500e+01 	 | already computed for i_cv=0, skipping.	| completed in 47.0m 32.1s |
# |key='num_delay':value=4.500e+01 	 | already computed for i_cv=1, skipping.	| completed in 45.0m 43.6s |
# |key='num_delay':value=5.000e+01 	 | already computed for i_cv=0, skipping.	| completed in 46.0m 18.6s |
# |key='num_delay':value=5.000e+01 	 | already computed for i_cv=1, skipping.	| completed in 46.0m 0.8s |
# |key='num_delay':value=5.500e+01 	 | already computed for i_cv=0, skipping.	| completed in 46.0m 55.4s |
# |key='num_delay':value=5.500e+01 	 | already computed for i_cv=1, skipping.	| completed in 48.0m 10.8s |
# |key='num_delay':value=6.000e+01 	 | already computed for i_cv=0, skipping.	| completed in 49.0m 8.9s |
# |key='num_delay':value=6.000e+01 	 | already computed for i_cv=1, skipping.	| completed in 49.0m 41.0s |
# --------------------------------------------------
# scanning key='N_neuron'
# --------------------------------------------------
# |key='N_neuron':value=5.000e+01 	 | already computed for i_cv=0, skipping.	| completed in 31.0m 58.7s |
# |key='N_neuron':value=5.000e+01 	 | already computed for i_cv=1, skipping.	| completed in 31.0m 22.2s |
# |key='N_neuron':value=6.700e+01 	 | already computed for i_cv=0, skipping.	| completed in 31.0m 19.4s |
# |key='N_neuron':value=6.700e+01 	 | already computed for i_cv=1, skipping.	| completed in 31.0m 27.9s |
# |key='N_neuron':value=9.200e+01 	 | already computed for i_cv=0, skipping.	| completed in 31.0m 23.3s |
# |key='N_neuron':value=9.200e+01 	 | already computed for i_cv=1, skipping.	| completed in 31.0m 19.0s |
# |key='N_neuron':value=1.250e+02 	 | already computed for i_cv=0, skipping.	| completed in 31.0m 30.3s |
# |key='N_neuron':value=1.250e+02 	 | already computed for i_cv=1, skipping.	| completed in 31.0m 30.3s |
# |key='N_neuron':value=1.700e+02 	 | already computed for i_cv=0, skipping.	| completed in 31.0m 43.9s |
# |key='N_neuron':value=1.700e+02 	 | already computed for i_cv=1, skipping.	| completed in 30.0m 41.4s |
# |key='N_neuron':value=2.320e+02 	 | already computed for i_cv=0, skipping.	| completed in 30.0m 29.6s |
# |key='N_neuron':value=2.320e+02 	 | already computed for i_cv=1, skipping.	| completed in 30.0m 20.8s |
# |key='N_neuron':value=3.160e+02 	 | already computed for i_cv=0, skipping.	| completed in 31.0m 30.0s |
# |key='N_neuron':value=3.160e+02 	 | already computed for i_cv=1, skipping.	| completed in 31.0m 39.4s |
# |key='N_neuron':value=4.300e+02 	 | already computed for i_cv=0, skipping.	| completed in 32.0m 45.3s |
# |key='N_neuron':value=4.300e+02 	 | already computed for i_cv=1, skipping.	| completed in 34.0m 36.4s |
# |key='N_neuron':value=5.840e+02 	 | already computed for i_cv=0, skipping.	| completed in 35.0m 44.9s |
# |key='N_neuron':value=5.840e+02 	 | already computed for i_cv=1, skipping.	| completed in 35.0m 42.7s |
# |key='N_neuron':value=7.950e+02 	 | already computed for i_cv=0, skipping.	| completed in 37.0m 44.3s |
# |key='N_neuron':value=7.950e+02 	 | already computed for i_cv=1, skipping.	| completed in 38.0m 37.3s |
# |key='N_neuron':value=1.081e+03 	 | already computed for i_cv=0, skipping.	| completed in 40.0m 37.0s |
# |key='N_neuron':value=1.081e+03 	 | already computed for i_cv=1, skipping.	| completed in 41.0m 32.5s |
# |key='N_neuron':value=1.470e+03 	 | already computed for i_cv=0, skipping.	| completed in 47.0m 20.7s |
# |key='N_neuron':value=1.470e+03 	 | already computed for i_cv=1, skipping.	| completed in 47.0m 22.2s |
# |key='N_neuron':value=2.000e+03 	 | already computed for i_cv=0, skipping.	| completed in 56.0m 6.8s |
# |key='N_neuron':value=2.000e+03 	 | already computed for i_cv=1, skipping.	| completed in 55.0m 36.4s |
# --------------------------------------------------
# scanning key='p_A'
# --------------------------------------------------
# |key='p_A':value=2.000e-04 	 | already computed for i_cv=0, skipping.	| completed in 47.0m 31.1s |
# |key='p_A':value=2.000e-04 	 | already computed for i_cv=1, skipping.	| completed in 55.0m 58.8s |
# |key='p_A':value=3.169e-04 	 | already computed for i_cv=0, skipping.	| completed in 52.0m 24.7s |
# |key='p_A':value=3.169e-04 	 | already computed for i_cv=1, skipping.	| completed in 53.0m 1.2s |
# |key='p_A':value=5.020e-04 	 | already computed for i_cv=0, skipping.	| completed in 53.0m 7.9s |
# |key='p_A':value=5.020e-04 	 | already computed for i_cv=1, skipping.	| completed in 52.0m 21.1s |
# |key='p_A':value=7.953e-04 	 | already computed for i_cv=0, skipping.	| completed in 52.0m 45.0s |
# |key='p_A':value=7.953e-04 	 | already computed for i_cv=1, skipping.	| completed in 53.0m 42.4s |
# |key='p_A':value=1.260e-03 	 | already computed for i_cv=0, skipping.	| completed in 52.0m 33.0s |
# |key='p_A':value=1.260e-03 	 | already computed for i_cv=1, skipping.	| completed in 52.0m 23.3s |
# |key='p_A':value=1.996e-03 	 | already computed for i_cv=0, skipping.	| completed in 53.0m 15.6s |
# |key='p_A':value=1.996e-03 	 | already computed for i_cv=1, skipping.	| completed in 51.0m 33.0s |
# |key='p_A':value=3.162e-03 	 | already computed for i_cv=0, skipping.	| completed in 52.0m 28.3s |
# |key='p_A':value=3.162e-03 	 | already computed for i_cv=1, skipping.	| completed in 52.0m 52.6s |
# |key='p_A':value=5.010e-03 	 | already computed for i_cv=0, skipping.	| completed in 53.0m 2.4s |
# |key='p_A':value=5.010e-03 	 | already computed for i_cv=1, skipping.	| completed in 52.0m 20.4s |
# |key='p_A':value=7.937e-03 	 | already computed for i_cv=0, skipping.	| completed in 52.0m 26.4s |
# |key='p_A':value=7.937e-03 	 | already computed for i_cv=1, skipping.	| completed in 52.0m 27.9s |
# |key='p_A':value=1.257e-02 	 | already computed for i_cv=0, skipping.	| completed in 51.0m 32.2s |
# |key='p_A':value=1.257e-02 	 | already computed for i_cv=1, skipping.	| completed in 51.0m 48.4s |
# |key='p_A':value=1.992e-02 	 | already computed for i_cv=0, skipping.	| completed in 49.0m 19.5s |
# |key='p_A':value=1.992e-02 	 | already computed for i_cv=1, skipping.	| completed in 49.0m 56.0s |
# |key='p_A':value=3.156e-02 	 | already computed for i_cv=0, skipping.	| completed in 49.0m 57.8s |
# |key='p_A':value=3.156e-02 	 | already computed for i_cv=1, skipping.	| completed in 50.0m 5.8s |
# |key='p_A':value=5.000e-02 	 | already computed for i_cv=0, skipping.	| completed in 51.0m 7.0s |
# |key='p_A':value=5.000e-02 	 | already computed for i_cv=1, skipping.	| completed in 51.0m 20.8s |
# --------------------------------------------------
# scanning key='lif_threshold'
# --------------------------------------------------
# |key='lif_threshold':value=2.000e-02 	 | already computed for i_cv=0, skipping.	| completed in 58.0m 11.0s |
# |key='lif_threshold':value=2.000e-02 	 | already computed for i_cv=1, skipping.	| completed in 61.0m 57.9s |
# |key='lif_threshold':value=1.725e-01 	 | already computed for i_cv=0, skipping.	| completed in 56.0m 27.9s |
# |key='lif_threshold':value=1.725e-01 	 | already computed for i_cv=1, skipping.	| completed in 57.0m 25.7s |
# |key='lif_threshold':value=3.250e-01 	 | already computed for i_cv=0, skipping.	| completed in 49.0m 25.2s |
# |key='lif_threshold':value=3.250e-01 	 | already computed for i_cv=1, skipping.	| completed in 56.0m 28.2s |
# |key='lif_threshold':value=4.775e-01 	 | already computed for i_cv=0, skipping.	| completed in 60.0m 36.1s |
# |key='lif_threshold':value=4.775e-01 	 | already computed for i_cv=1, skipping.	| completed in 58.0m 26.4s |
# |key='lif_threshold':value=6.300e-01 	 | already computed for i_cv=0, skipping.	| completed in 59.0m 23.4s |
# |key='lif_threshold':value=6.300e-01 	 | already computed for i_cv=1, skipping.	| completed in 60.0m 48.1s |
# |key='lif_threshold':value=7.825e-01 	 | already computed for i_cv=0, skipping.	| completed in 49.0m 18.1s |
# |key='lif_threshold':value=7.825e-01 	 | already computed for i_cv=1, skipping.	| completed in 48.0m 29.3s |
# |key='lif_threshold':value=9.350e-01 	 | already computed for i_cv=0, skipping.	| completed in 49.0m 42.0s |
# |key='lif_threshold':value=9.350e-01 	 | already computed for i_cv=1, skipping.	| completed in 49.0m 15.1s |
# |key='lif_threshold':value=1.087e+00 	 | already computed for i_cv=0, skipping.	| completed in 49.0m 53.7s |
# |key='lif_threshold':value=1.087e+00 	 | already computed for i_cv=1, skipping.	| completed in 50.0m 33.2s |
# |key='lif_threshold':value=1.240e+00 	 | already computed for i_cv=0, skipping.	| completed in 53.0m 1.3s |
# |key='lif_threshold':value=1.240e+00 	 | already computed for i_cv=1, skipping.	| completed in 49.0m 54.0s |
# |key='lif_threshold':value=1.393e+00 	 | already computed for i_cv=0, skipping.	| completed in 51.0m 21.5s |
# |key='lif_threshold':value=1.393e+00 	 | already computed for i_cv=1, skipping.	| completed in 50.0m 42.4s |
# |key='lif_threshold':value=1.545e+00 	 | already computed for i_cv=0, skipping.	| completed in 50.0m 12.5s |
# |key='lif_threshold':value=1.545e+00 	 | already computed for i_cv=1, skipping.	| completed in 53.0m 43.3s |
# |key='lif_threshold':value=1.698e+00 	 | already computed for i_cv=0, skipping.	| completed in 48.0m 11.7s |
# |key='lif_threshold':value=1.698e+00 	 | already computed for i_cv=1, skipping.	| completed in 48.0m 35.8s |
# |key='lif_threshold':value=1.850e+00 	 | already computed for i_cv=0, skipping.	| completed in 49.0m 24.8s |
# |key='lif_threshold':value=1.850e+00 	 | already computed for i_cv=1, skipping.	| completed in 48.0m 58.6s |
# --------------------------------------------------
# scanning key='do_deconv'
# --------------------------------------------------
# |key='do_deconv':value=1.000e+00 	 | already computed for i_cv=0, skipping.	| completed in 37.0m 23.6s |
# |key='do_deconv':value=1.000e+00 	 | already computed for i_cv=1, skipping.	| completed in 38.0m 4.4s |
# |key='do_deconv':value=0.000e+00 	 | already computed for i_cv=0, skipping.	| completed in 37.0m 51.5s |
# |key='do_deconv':value=0.000e+00 	 | already computed for i_cv=1, skipping.	| completed in 37.0m 30.9s |
# --------------------------------------------------
# scanning key='do_pinv'
# --------------------------------------------------
# |key='do_pinv':value=1.000e+00 	 | already computed for i_cv=0, skipping.	| completed in 137.0m 9.9s |
# |key='do_pinv':value=1.000e+00 	 | already computed for i_cv=1, skipping.	| completed in 141.0m 1.0s |
# |key='do_pinv':value=0.000e+00 	 | already computed for i_cv=0, skipping.	| completed in 116.0m 41.4s |
# |key='do_pinv':value=0.000e+00 	 | already computed for i_cv=1, skipping.	| completed in 114.0m 46.3s |
# --------------------------------------------------
# scanning key='N_pattern'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-07-11_scan_N_pattern.json')...
#     N_pattern  i_cv      loss         time
# 0           1     0  0.019718  2203.382809
# 1           1     1  0.040293  2120.862136
# 2           3     0  0.019209  2190.430195
# 3           3     1  0.221354  2129.518169
# 4           5     0  0.019124  2334.874207
# 5           5     1  0.016710  2165.409141
# 6           7     0  0.100450  2289.418661
# 7           7     1  0.189781  2359.775375
# 8           9     0  0.066863  2466.641494
# 9           9     1  0.071429  2648.655437
# 10         11     0  0.147392  2665.013034
# 11         11     1  0.042791  2448.326256
# 12         13     0  0.067073  2764.117472
# 13         13     1  0.148384  3055.638086
# 14         15     0  0.207046  2392.180838
# 15         15     1  0.148482  3317.967844
# 16         17     0  0.083436  2678.416405
# 17         17     1  0.140490  3408.736804
# 18         19     0  0.080308  3395.325219
# 19         19     1  0.149150  3361.914252
# 20         21     0  0.060293  3573.654563
# 21         21     1  0.152207  3500.997794
# 22         23     0  0.217687  3806.327481
# 23         23     1  0.179753  3791.407958
# 24         26     0  0.142055  4182.885037
# 25         26     1  0.180726  3905.474540
# Saving as ../figures/scan_N_pattern.pdf
# Saving as ../figures/scan_N_pattern.png
# Saving as ../figures/scan_N_pattern.svg
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# --------------------------------------------------
# scanning key='N_time'
# --------------------------------------------------
# --------------------------------------------------
# scanning key='num_delay'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-07-11_scan_num_delay.json')...
#     num_delay  i_cv      loss         time
# 0           1     0  1.000000  1934.464965
# 1           1     1  1.000000  1906.581120
# 2           5     0  0.999213  1935.343320
# 3           5     1  0.999225  1941.645155
# 4          10     0  0.991888  1985.102051
# 5          10     1  0.999225  1974.001105
# 6          15     0  0.999596  2039.177556
# 7          15     1  0.999619  2027.529471
# 8          20     0  0.950148  2168.249344
# 9          20     1  0.903759  2170.727965
# 10         25     0  0.833956  2320.015960
# 11         25     1  0.718770  2308.571532
# 12         30     0  0.493409  2471.561068
# 13         30     1  0.437326  2480.537718
# 14         35     0  0.207449  2648.359713
# 15         35     1  0.300899  2615.612074
# 16         40     0  0.135505  2813.116712
# 17         40     1  0.206264  2826.463108
# 18         45     0  0.101065  2852.108814
# 19         45     1  0.087287  2743.600383
# 20         50     0  0.055478  2778.620847
# 21         50     1  0.024481  2760.796360
# 22         55     0  0.020589  2815.355682
# 23         55     1  0.080420  2890.825394
# 24         60     0  0.020240  2948.928801
# 25         60     1  0.019342  2980.991139
# Saving as ../figures/scan_num_delay.pdf
# Saving as ../figures/scan_num_delay.png
# Saving as ../figures/scan_num_delay.svg
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# --------------------------------------------------
# scanning key='N_neuron'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-07-11_scan_N_neuron.json')...
#     N_neuron  i_cv      loss         time
# 0         50     0  1.000000  1918.712022
# 1         50     1  1.000000  1882.154782
# 2         67     0  1.000000  1879.428992
# 3         67     1  0.988235  1887.872208
# 4         92     0  1.000000  1883.279560
# 5         92     1  1.000000  1879.006680
# 6        125     0  1.000000  1890.341298
# 7        125     1  0.993289  1890.332745
# 8        170     0  0.990148  1903.902503
# 9        170     1  0.981818  1841.395059
# 10       232     0  0.993139  1829.619754
# 11       232     1  0.996241  1820.794328
# 12       316     0  0.985167  1890.016030
# 13       316     1  0.971522  1899.434079
# 14       430     0  0.999448  1965.344791
# 15       430     1  0.998236  2076.350939
# 16       584     0  0.707110  2144.851013
# 17       584     1  0.664357  2142.707674
# 18       795     0  0.389461  2264.338078
# 19       795     1  0.202983  2317.295765
# 20      1081     0  0.107375  2437.007296
# 21      1081     1  0.066693  2492.469494
# 22      1470     0  0.058175  2840.688184
# 23      1470     1  0.020557  2842.190802
# 24      2000     0  0.017954  3366.819993
# 25      2000     1  0.018495  3336.354742
# Saving as ../figures/scan_N_neuron.pdf
# Saving as ../figures/scan_N_neuron.png
# Saving as ../figures/scan_N_neuron.svg
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# --------------------------------------------------
# scanning key='p_A'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-07-11_scan_p_A.json')...
#          p_A  i_cv      loss         time
# 0   0.000200     0  0.056799  2851.117195
# 1   0.000200     1  0.050404  3358.760723
# 2   0.000317     0  0.021179  3144.749788
# 3   0.000317     1  0.020292  3181.174640
# 4   0.000502     0  0.019994  3187.870227
# 5   0.000502     1  0.021201  3141.069012
# 6   0.000795     0  0.021835  3164.981448
# 7   0.000795     1  0.021668  3222.428529
# 8   0.001260     0  0.023906  3153.024898
# 9   0.001260     1  0.024672  3143.309557
# 10  0.001996     0  0.027591  3195.594650
# 11  0.001996     1  0.025526  3092.982529
# 12  0.003162     0  0.031303  3148.279782
# 13  0.003162     1  0.032556  3172.597395
# 14  0.005010     0  0.039952  3182.372030
# 15  0.005010     1  0.039060  3140.432621
# 16  0.007937     0  0.055771  3146.362508
# 17  0.007937     1  0.055595  3147.881609
# 18  0.012574     0  0.650874  3092.194323
# 19  0.012574     1  0.662110  3108.440465
# 20  0.019921     0  0.907459  2959.465308
# 21  0.019921     1  0.904887  2996.009380
# 22  0.031560     0  0.937773  2997.834185
# 23  0.031560     1  0.939006  3005.777002
# 24  0.050000     0  0.951738  3066.994794
# 25  0.050000     1  0.952818  3080.796545
# Saving as ../figures/scan_p_A.pdf
# Saving as ../figures/scan_p_A.png
# Saving as ../figures/scan_p_A.svg
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# --------------------------------------------------
# scanning key='lif_threshold'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-07-11_scan_lif_threshold.json')...
#     lif_threshold  i_cv      loss         time
# 0          0.0200     0  0.999584  3490.988361
# 1          0.0200     1  0.999588  3717.910485
# 2          0.1725     0  0.998454  3387.887578
# 3          0.1725     1  0.998037  3445.736256
# 4          0.3250     0  0.521193  2965.207407
# 5          0.3250     1  0.622293  3388.248767
# 6          0.4775     0  0.120785  3636.108340
# 7          0.4775     1  0.316506  3506.394090
# 8          0.6300     0  0.175855  3563.351851
# 9          0.6300     1  0.127273  3648.095795
# 10         0.7825     0  0.149181  2958.121519
# 11         0.7825     1  0.058690  2909.302168
# 12         0.9350     0  0.101182  2982.009372
# 13         0.9350     1  0.184162  2955.142205
# 14         1.0875     0  1.000000  2993.734943
# 15         1.0875     1  1.000000  3033.190011
# 16         1.2400     0  1.000000  3181.296378
# 17         1.2400     1  1.000000  2994.026955
# 18         1.3925     0  1.000000  3081.450993
# 19         1.3925     1  1.000000  3042.370350
# 20         1.5450     0  1.000000  3012.486352
# 21         1.5450     1  1.000000  3223.267607
# 22         1.6975     0  1.000000  2891.676501
# 23         1.6975     1  1.000000  2915.816399
# 24         1.8500     0  1.000000  2964.760670
# 25         1.8500     1  1.000000  2938.636997
# Saving as ../figures/scan_lif_threshold.pdf
# Saving as ../figures/scan_lif_threshold.png
# Saving as ../figures/scan_lif_threshold.svg
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# --------------------------------------------------
# scanning key='do_deconv'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-07-11_scan_do_deconv.json')...
#    do_deconv  i_cv      loss         time
# 0       True     0  0.130400  2243.603872
# 1       True     1  0.094490  2284.405033
# 2      False     0  0.077179  2271.463931
# 3      False     1  0.104869  2250.868042
# Saving as ../figures/scan_do_deconv.pdf
# Saving as ../figures/scan_do_deconv.png
# Saving as ../figures/scan_do_deconv.svg
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# --------------------------------------------------
# scanning key='do_pinv'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-07-11_scan_do_pinv.json')...
#    do_pinv  i_cv      loss         time
# 0     True     0  0.130400  8229.903936
# 1     True     1  0.094490  8460.971738
# 2    False     0  0.998393  7001.396451
# 3    False     1  0.998478  6886.265104
# Saving as ../figures/scan_do_pinv.pdf
# Saving as ../figures/scan_do_pinv.png
# Saving as ../figures/scan_do_pinv.svg
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# ==================================================================================
# Scanning stimulus-generation parameters to measure sensitivity to input statistics
# ==================================================================================
# --------------------------------------------------
# scanning key='p_flip'
# --------------------------------------------------
# Done |i_cv=0| 1/13	Done |i_cv=1| 1/13	Doing |i_cv=0| 2/13	Doing |i_cv=1| 2/13	Doing |i_cv=0| 3/13	Doing |i_cv=1| 3/13	Doing |i_cv=0| 4/13	Doing |i_cv=1| 4/13	Doing |i_cv=0| 5/13	Doing |i_cv=1| 5/13	Doing |i_cv=0| 6/13	Doing |i_cv=1| 6/13	Doing |i_cv=0| 7/13	Doing |i_cv=1| 7/13	Doing |i_cv=0| 8/13	Doing |i_cv=1| 8/13	Doing |i_cv=0| 9/13	Doing |i_cv=1| 9/13	Doing |i_cv=0| 10/13	Doing |i_cv=1| 10/13	Doing |i_cv=0| 11/13	Doing |i_cv=1| 11/13	Doing |i_cv=0| 12/13	Doing |i_cv=1| 12/13	Doing |i_cv=0| 13/13	Doing |i_cv=1| 13/13	--------------------------------------------------
# scanning key='p_flip'
# --------------------------------------------------
# |key='p_flip':value=1.000e-05 	| already computed for i_cv=0, skipping.	| completed in 38.0m 19.5s |
# |key='p_flip':value=1.000e-05 	| already computed for i_cv=1, skipping.	| completed in 38.0m 2.2s |
# |key='p_flip':value=1.778e-05 	| already computed for i_cv=0, skipping.	| completed in 41.0m 32.2s |
# |key='p_flip':value=1.778e-05 	| already computed for i_cv=1, skipping.	| completed in 38.0m 40.0s |
# |key='p_flip':value=3.162e-05 	| already computed for i_cv=0, skipping.	| completed in 39.0m 34.2s |
# |key='p_flip':value=3.162e-05 	| already computed for i_cv=1, skipping.	| completed in 38.0m 1.6s |
# |key='p_flip':value=5.623e-05 	| already computed for i_cv=0, skipping.	| completed in 39.0m 45.7s |
# |key='p_flip':value=5.623e-05 	| already computed for i_cv=1, skipping.	| completed in 40.0m 3.2s |
# |key='p_flip':value=1.000e-04 	| already computed for i_cv=0, skipping.	| completed in 38.0m 34.1s |
# |key='p_flip':value=1.000e-04 	| already computed for i_cv=1, skipping.	| completed in 38.0m 32.7s |
# |key='p_flip':value=1.778e-04 	| already computed for i_cv=0, skipping.	| completed in 38.0m 45.4s |
# |key='p_flip':value=1.778e-04 	| already computed for i_cv=1, skipping.	| completed in 38.0m 14.0s |
# |key='p_flip':value=3.162e-04 	| already computed for i_cv=0, skipping.	| completed in 38.0m 25.2s |
# |key='p_flip':value=3.162e-04 	| already computed for i_cv=1, skipping.	| completed in 40.0m 27.2s |
# |key='p_flip':value=5.623e-04 	| already computed for i_cv=0, skipping.	| completed in 38.0m 28.4s |
# |key='p_flip':value=5.623e-04 	| already computed for i_cv=1, skipping.	| completed in 42.0m 56.3s |
# |key='p_flip':value=1.000e-03 	| already computed for i_cv=0, skipping.	| completed in 38.0m 11.1s |
# |key='p_flip':value=1.000e-03 	| already computed for i_cv=1, skipping.	| completed in 42.0m 46.9s |
# |key='p_flip':value=1.778e-03 	| already computed for i_cv=0, skipping.	| completed in 37.0m 50.3s |
# |key='p_flip':value=1.778e-03 	| already computed for i_cv=1, skipping.	| completed in 38.0m 0.1s |
# |key='p_flip':value=3.162e-03 	| already computed for i_cv=0, skipping.	| completed in 37.0m 37.0s |
# |key='p_flip':value=3.162e-03 	| already computed for i_cv=1, skipping.	| completed in 38.0m 10.9s |
# |key='p_flip':value=5.623e-03 	| already computed for i_cv=0, skipping.	| completed in 38.0m 5.5s |
# |key='p_flip':value=5.623e-03 	| already computed for i_cv=1, skipping.	| completed in 37.0m 48.5s |
# |key='p_flip':value=1.000e-02 	| already computed for i_cv=0, skipping.	| completed in 39.0m 5.0s |
# |key='p_flip':value=1.000e-02 	| already computed for i_cv=1, skipping.	| completed in 38.0m 48.9s |
# --------------------------------------------------
# scanning key='p_flip'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-07-11_scan_p_flip.json')...
#       p_flip  i_cv      loss         time
# 0   0.000010     0  0.004971  2299.476328
# 1   0.000010     1  0.048479  2282.238554
# 2   0.000018     0  0.015348  2492.239828
# 3   0.000018     1  0.152373  2319.966988
# 4   0.000032     0  0.096632  2374.223305
# 5   0.000032     1  0.148302  2281.576834
# 6   0.000056     0  0.089122  2385.682494
# 7   0.000056     1  0.039864  2403.153266
# 8   0.000100     0  0.031588  2314.147540
# 9   0.000100     1  0.101768  2312.661614
# 10  0.000178     0  0.123475  2325.356864
# 11  0.000178     1  0.102770  2294.044607
# 12  0.000316     0  0.088591  2305.176839
# 13  0.000316     1  0.113654  2427.182504
# 14  0.000562     0  0.064392  2308.418136
# 15  0.000562     1  0.099407  2576.318752
# 16  0.001000     0  0.053035  2291.087514
# 17  0.001000     1  0.038007  2566.905742
# 18  0.001778     0  0.120355  2270.260606
# 19  0.001778     1  0.034962  2280.106387
# 20  0.003162     0  0.057718  2256.960314
# 21  0.003162     1  0.087674  2290.910607
# 22  0.005623     0  0.103538  2285.461910
# 23  0.005623     1  0.111111  2268.453306
# 24  0.010000     0  0.065001  2344.958610
# 25  0.010000     1  0.128133  2328.856948
# Saving as ../figures/scan_p_flip.pdf
# Saving as ../figures/scan_p_flip.png
# Saving as ../figures/scan_p_flip.svg
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# ✅ END: 2026-07-29 17:44:50

# %%
pprint("🚀 Running: 25_MNESIS_optuna.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 25_MNESIS_optuna.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# =================================
# 🚀 Running: 25_MNESIS_optuna.ipynb
# =================================
# ⏱️  START: 2026-07-29 17:44:50
# ===================================================================================================
# Optimizing learning parameters with Optuna: running hyperparameter search and analyzing best trials
# ===================================================================================================
# -rw-r-----@ 1 laurent  staff  458752 19 juil. 13:32 ../cached_data/2026-07-11_optuna.sqlite3
# Optuna file not found or unlocked: ../cached_data/2026-07-11_optuna.sqlite3, starting optimization.
# So far, Best params:  {'do_deconv': True, 'do_pinv': True, 'lif_beta': 0.7805389151808955, 'alpha_surrogate': 4.683052966350581, 'base_lr': 0.03237467811738326, 'final_lr': 0.0008918137801946452, 'delta1': 0.007930028567334364, 'delta2': 1.020749132568178e-05, 'dropout': 0.2522248421519857, 'lif_threshold': 0.7264548492192898}, Best value:  0.10534405708312988
# Starting optimization on 0 trials with 200 existing trials.
# number of trials in study: 200
# -.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.
# Best params:  {'do_deconv': True, 'do_pinv': True, 'lif_beta': 0.7805389151808955, 'alpha_surrogate': 4.683052966350581, 'base_lr': 0.03237467811738326, 'final_lr': 0.0008918137801946452, 'delta1': 0.007930028567334364, 'delta2': 1.020749132568178e-05, 'dropout': 0.2522248421519857, 'lif_threshold': 0.7264548492192898}
# Best value:  0.10534405708312988
# ============================================================
# OPTUNA STUDY ANALYSIS
# ============================================================
#
# [1] PARAMETER IMPORTANCE RANKING:
# lif_threshold                 : 0.787
# do_pinv                       : 0.167
# lif_beta                      : 0.016
# delta1                        : 0.012
# dropout                       : 0.008
# base_lr                       : 0.006
# final_lr                      : 0.002
# alpha_surrogate               : 0.001
# delta2                        : 0.001
# do_deconv                     : 0.001
#
# [2] BEST VALUES WITH CONFIDENCE INTERVALS:
#
# Best Objective Value: 0.10534
#
# Estimated Confidence Intervals (Top 10% Trials):
# do_deconv	: Best=True,	 Most Common=True, True: 10/19 (52.6%)
# do_pinv	: Best=True,	 Most Common=True, True: 16/19 (84.2%)
# lif_beta	: Best=7.805389e-01,	 Median=7.143e-01, 90% CI=[2.282e-01, 9.513e-01]
# alpha_surrogate	: Best=4.683053e+00,	 Median=6.893e+00, 90% CI=[3.365e+00, 2.936e+01]
# base_lr	: Best=3.237468e-02,	 Median=3.234e-02, 90% CI=[8.182e-03, 6.011e-02]
# final_lr	: Best=8.918138e-04,	 Median=6.817e-04, 90% CI=[1.456e-04, 1.159e-03]
# delta1	: Best=7.930029e-03,	 Median=1.046e-02, 90% CI=[6.086e-03, 3.442e-02]
# delta2	: Best=1.020749e-05,	 Median=1.246e-05, 90% CI=[6.419e-06, 4.336e-05]
# dropout	: Best=2.522248e-01,	 Median=2.719e-01, 90% CI=[2.617e-02, 5.925e-01]
# lif_threshold	: Best=7.264548e-01,	 Median=1.232e+00, 90% CI=[8.035e-01, 2.055e+00]
#
# ============================================================
# ✅ END: 2026-07-29 17:44:54

# %%
pprint("🚀 Running: 30_MNESIS_learn-periodic.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 30_MNESIS_learn-periodic.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# =========================================
# 🚀 Running: 30_MNESIS_learn-periodic.ipynb
# =========================================
# ⏱️  START: 2026-07-29 17:44:54
# Model weights loaded from ../cached_data/2026-07-11_periodic.pth
# precision = 0.894	 recall = 0.944	 f1_score = 0.918
# Model weights loaded from ../cached_data/2026-07-11_periodic_spikes.pth
# precision = 0.861	 recall = 0.812	 f1_score = 0.836
# Model weights loaded from ../cached_data/2026-07-11_periodic_spikes_noisy.pth
# precision = 0.680	 recall = 0.317	 f1_score = 0.432
# Score weights loaded from ../cached_data/2026-07-11_periodic.pth
# ✅ END: 2026-07-29 17:44:57

# %%
pprint("🚀 Running: 32_MNESIS_learn-travelling-waves.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 32_MNESIS_learn-travelling-waves.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# =================================================
# 🚀 Running: 32_MNESIS_learn-travelling-waves.ipynb
# =================================================
# ⏱️  START: 2026-07-29 17:44:57
# =========================================================================
# Defining traveling wave patterns and building the spike-pattern generator
# =========================================================================
# ======================================================
# Learning traveling wave patterns with the HD_SNN model
# ======================================================
# Model weights loaded from ../cached_data/2026-07-11_TW.pth
# precision = 0.670	 recall = 1.000	 f1_score = 0.803
# ==============================================================
# Running long traveling-wave evaluation over repeated sequences
# ==============================================================
# precision = 0.745	 recall = 1.000	 f1_score = 0.854
# ========================================================================
# Running long traveling-wave evaluation with multiple pattern transitions
# ========================================================================
# ================================================================
# Optimizing learning parameters with Optuna hyperparameter search
# ================================================================
# -rw-r-----@ 1 laurent  staff  393216 29 juil. 17:08 ../cached_data/2026-07-11_TW_optuna.sqlite3
# Optuna file is locked: ../cached_data/2026-07-11_TW_optuna.lock, passing.
# Study is None (likely due to lock), skipping load.
# Study is None, skipping trials display.
# Study is None, skipping best-trial summary.
# Study is None, skipping parameter-importance plot.
# Study is None, skipping diagnostic plots.
# ==========================================================================
# Scanning network parameters to measure sensitivity of learning performance
# ==========================================================================
# --------------------------------------------------
# scanning key='p_A'
# --------------------------------------------------
# --------------------------------------------------
# scanning key='lif_threshold'
# --------------------------------------------------
# |key='lif_threshold':value=1.000e-01 	| already computed for i_cv=0, skipping.	| completed in 41.0m 43.2s |
# |key='lif_threshold':value=1.000e-01 	| already computed for i_cv=1, skipping.	| completed in 40.0m 10.6s |
# |key='lif_threshold':value=1.750e-01 	| already computed for i_cv=0, skipping.	| completed in 40.0m 27.1s |
# |key='lif_threshold':value=1.750e-01 	| already computed for i_cv=1, skipping.	| completed in 38.0m 9.6s |
# |key='lif_threshold':value=2.500e-01 	| already computed for i_cv=0, skipping.	| completed in 38.0m 17.0s |
# |key='lif_threshold':value=2.500e-01 	| already computed for i_cv=1, skipping.	| completed in 37.0m 56.3s |
# |key='lif_threshold':value=3.250e-01 	| already computed for i_cv=0, skipping.	| completed in 37.0m 57.9s |
# |key='lif_threshold':value=3.250e-01 	| already computed for i_cv=1, skipping.	| completed in 38.0m 5.3s |
# |key='lif_threshold':value=4.000e-01 	| already computed for i_cv=0, skipping.	| completed in 38.0m 37.3s |
# |key='lif_threshold':value=4.000e-01 	| already computed for i_cv=1, skipping.	| completed in 38.0m 22.5s |
# |key='lif_threshold':value=4.750e-01 	| already computed for i_cv=0, skipping.	| completed in 38.0m 59.0s |
# |key='lif_threshold':value=4.750e-01 	| already computed for i_cv=1, skipping.	| completed in 39.0m 23.3s |
# |key='lif_threshold':value=5.500e-01 	| already computed for i_cv=0, skipping.	| completed in 40.0m 10.5s |
# |key='lif_threshold':value=5.500e-01 	| already computed for i_cv=1, skipping.	| completed in 38.0m 45.0s |
# |key='lif_threshold':value=6.250e-01 	| already computed for i_cv=0, skipping.	| completed in 39.0m 6.9s |
# |key='lif_threshold':value=6.250e-01 	| already computed for i_cv=1, skipping.	| completed in 39.0m 25.6s |
# |key='lif_threshold':value=7.000e-01 	| already computed for i_cv=0, skipping.	| completed in 39.0m 9.1s |
# |key='lif_threshold':value=7.000e-01 	| already computed for i_cv=1, skipping.	| completed in 39.0m 8.2s |
# |key='lif_threshold':value=7.750e-01 	| already computed for i_cv=0, skipping.	| completed in 39.0m 31.1s |
# |key='lif_threshold':value=7.750e-01 	| already computed for i_cv=1, skipping.	| completed in 39.0m 1.7s |
# |key='lif_threshold':value=8.500e-01 	| already computed for i_cv=0, skipping.	| completed in 38.0m 54.6s |
# |key='lif_threshold':value=8.500e-01 	| already computed for i_cv=1, skipping.	| completed in 38.0m 53.6s |
# |key='lif_threshold':value=9.250e-01 	| already computed for i_cv=0, skipping.	| completed in 38.0m 31.8s |
# |key='lif_threshold':value=9.250e-01 	| already computed for i_cv=1, skipping.	| completed in 38.0m 34.3s |
# |key='lif_threshold':value=1.000e+00 	| already computed for i_cv=0, skipping.	| completed in 39.0m 0.9s |
# |key='lif_threshold':value=1.000e+00 	| already computed for i_cv=1, skipping.	| completed in 39.0m 23.0s |
# --------------------------------------------------
# scanning key='do_deconv'
# --------------------------------------------------
# |key='do_deconv':value=1.000e+00 	| already computed for i_cv=0, skipping.	| completed in 41.0m 49.9s |
# |key='do_deconv':value=1.000e+00 	| already computed for i_cv=1, skipping.	| completed in 41.0m 32.7s |
# |key='do_deconv':value=0.000e+00 	| already computed for i_cv=0, skipping.	| completed in 42.0m 0.8s |
# |key='do_deconv':value=0.000e+00 	| already computed for i_cv=1, skipping.	| completed in 41.0m 51.5s |
# --------------------------------------------------
# scanning key='do_pinv'
# --------------------------------------------------
# |key='do_pinv':value=1.000e+00 	| already computed for i_cv=0, skipping.	| completed in 39.0m 18.5s |
# |key='do_pinv':value=1.000e+00 	| already computed for i_cv=1, skipping.	| completed in 39.0m 7.8s |
# |key='do_pinv':value=0.000e+00 	| already computed for i_cv=0, skipping.	| completed in 32.0m 7.9s |
# |key='do_pinv':value=0.000e+00 	| already computed for i_cv=1, skipping.	| completed in 32.0m 12.2s |
# --------------------------------------------------
# scanning key='p_A'
# --------------------------------------------------
# --------------------------------------------------
# scanning key='lif_threshold'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-07-11_TW_scan_lif_threshold.json')...
#     lif_threshold  i_cv      loss         time
# 0           0.100     0  0.999474  2503.172991
# 1           0.100     1  0.999482  2410.606716
# 2           0.175     0  0.848701  2427.138859
# 3           0.175     1  0.865806  2289.622299
# 4           0.250     0  0.577307  2296.992484
# 5           0.250     1  0.528247  2276.279881
# 6           0.325     0  0.358346  2277.888607
# 7           0.325     1  0.397050  2285.291229
# 8           0.400     0  0.212113  2317.276397
# 9           0.400     1  0.275175  2302.492486
# 10          0.475     0  0.139030  2338.986194
# 11          0.475     1  0.093924  2363.252959
# 12          0.550     0  0.106033  2410.467122
# 13          0.550     1  0.074602  2324.952361
# 14          0.625     0  0.056087  2346.881820
# 15          0.625     1  0.094694  2365.576371
# 16          0.700     0  0.043771  2349.124646
# 17          0.700     1  0.054732  2348.175086
# 18          0.775     0  0.016603  2371.117891
# 19          0.775     1  0.080847  2341.718842
# 20          0.850     0  0.064295  2334.575346
# 21          0.850     1  0.023354  2333.614697
# 22          0.925     0  0.177369  2311.844343
# 23          0.925     1  0.148191  2314.291180
# 24          1.000     0  0.893088  2340.896445
# 25          1.000     1  0.913270  2362.996314
# Saving as ../figures/scan_TW_lif_threshold.pdf
# Saving as ../figures/scan_TW_lif_threshold.png
# Saving as ../figures/scan_TW_lif_threshold.svg
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# --------------------------------------------------
# scanning key='do_deconv'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-07-11_TW_scan_do_deconv.json')...
#    do_deconv  i_cv      loss         time
# 0       True     0  0.261409  2509.887763
# 1       True     1  0.298491  2492.716176
# 2      False     0  0.999284  2520.797812
# 3      False     1  0.999237  2511.507505
# Saving as ../figures/scan_TW_do_deconv.pdf
# Saving as ../figures/scan_TW_do_deconv.png
# Saving as ../figures/scan_TW_do_deconv.svg
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# --------------------------------------------------
# scanning key='do_pinv'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-07-11_TW_scan_do_pinv.json')...
#    do_pinv  i_cv      loss         time
# 0     True     0  0.261409  2358.451663
# 1     True     1  0.298491  2347.815983
# 2    False     0  0.999419  1927.945561
# 3    False     1  0.999426  1932.234672
# Saving as ../figures/scan_TW_do_pinv.pdf
# Saving as ../figures/scan_TW_do_pinv.png
# Saving as ../figures/scan_TW_do_pinv.svg
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# ========================================================================
# Scanning stimulus parameters to evaluate robustness across wave settings
# ========================================================================
# --------------------------------------------------
# scanning key='movie_gain'
# --------------------------------------------------
# |key='movie_gain':value=5.000e+00 	| already computed for i_cv=0, skipping.	| completed in 60.0m 15.9s |
# |key='movie_gain':value=5.000e+00 	| already computed for i_cv=1, skipping.	| completed in 61.0m 53.4s |
# |key='movie_gain':value=5.297e+00 	| already computed for i_cv=0, skipping.	| completed in 62.0m 16.0s |
# |key='movie_gain':value=5.297e+00 	| already computed for i_cv=1, skipping.	| completed in 61.0m 52.3s |
# |key='movie_gain':value=5.612e+00 	| already computed for i_cv=0, skipping.	| completed in 61.0m 4.4s |
# |key='movie_gain':value=5.612e+00 	| already computed for i_cv=1, skipping.	| completed in 63.0m 54.0s |
# |key='movie_gain':value=5.946e+00 	| already computed for i_cv=0, skipping.	| completed in 69.0m 48.7s |
# |key='movie_gain':value=5.946e+00 	| already computed for i_cv=1, skipping.	| completed in 56.0m 52.7s |
# |key='movie_gain':value=6.300e+00 	| already computed for i_cv=0, skipping.	| completed in 56.0m 35.6s |
# |key='movie_gain':value=6.300e+00 	| already computed for i_cv=1, skipping.	| completed in 66.0m 25.6s |
# |key='movie_gain':value=6.674e+00 	| already computed for i_cv=0, skipping.	| completed in 63.0m 27.2s |
# |key='movie_gain':value=6.674e+00 	| already computed for i_cv=1, skipping.	| completed in 64.0m 23.7s |
# |key='movie_gain':value=7.071e+00 	| already computed for i_cv=0, skipping.	| completed in 63.0m 22.8s |
# |key='movie_gain':value=7.071e+00 	| already computed for i_cv=1, skipping.	| completed in 64.0m 13.2s |
# |key='movie_gain':value=7.492e+00 	| already computed for i_cv=0, skipping.	| completed in 54.0m 52.2s |
# |key='movie_gain':value=7.492e+00 	| already computed for i_cv=1, skipping.	| completed in 52.0m 44.6s |
# |key='movie_gain':value=7.937e+00 	| already computed for i_cv=0, skipping.	| completed in 55.0m 25.6s |
# |key='movie_gain':value=7.937e+00 	| already computed for i_cv=1, skipping.	| completed in 53.0m 56.9s |
# |key='movie_gain':value=8.409e+00 	| already computed for i_cv=0, skipping.	| completed in 56.0m 45.9s |
# |key='movie_gain':value=8.409e+00 	| already computed for i_cv=1, skipping.	| completed in 57.0m 53.1s |
# |key='movie_gain':value=8.909e+00 	| already computed for i_cv=0, skipping.	| completed in 59.0m 13.4s |
# |key='movie_gain':value=8.909e+00 	| already computed for i_cv=1, skipping.	| completed in 59.0m 0.5s |
# |key='movie_gain':value=9.439e+00 	| already computed for i_cv=0, skipping.	| completed in 59.0m 41.7s |
# |key='movie_gain':value=9.439e+00 	| already computed for i_cv=1, skipping.	| completed in 57.0m 52.6s |
# |key='movie_gain':value=1.000e+01 	| already computed for i_cv=0, skipping.	| completed in 57.0m 1.8s |
# |key='movie_gain':value=1.000e+01 	| already computed for i_cv=1, skipping.	| completed in 56.0m 8.6s |
# --------------------------------------------------
# scanning key='sf_0'
# --------------------------------------------------
# |key='sf_0':value=1.000e-02 	| already computed for i_cv=0, skipping.	| completed in 39.0m 1.9s |
# |key='sf_0':value=1.000e-02 	| already computed for i_cv=1, skipping.	| completed in 39.0m 5.0s |
# |key='sf_0':value=1.373e-02 	| already computed for i_cv=0, skipping.	| completed in 38.0m 55.9s |
# |key='sf_0':value=1.373e-02 	| already computed for i_cv=1, skipping.	| completed in 39.0m 8.9s |
# |key='sf_0':value=1.886e-02 	| already computed for i_cv=0, skipping.	| completed in 39.0m 7.6s |
# |key='sf_0':value=1.886e-02 	| already computed for i_cv=1, skipping.	| completed in 38.0m 53.3s |
# |key='sf_0':value=2.590e-02 	| already computed for i_cv=0, skipping.	| completed in 39.0m 5.6s |
# |key='sf_0':value=2.590e-02 	| already computed for i_cv=1, skipping.	| completed in 38.0m 45.6s |
# |key='sf_0':value=3.557e-02 	| already computed for i_cv=0, skipping.	| completed in 38.0m 43.4s |
# |key='sf_0':value=3.557e-02 	| already computed for i_cv=1, skipping.	| completed in 37.0m 36.2s |
# |key='sf_0':value=4.885e-02 	| already computed for i_cv=0, skipping.	| completed in 37.0m 28.8s |
# |key='sf_0':value=4.885e-02 	| already computed for i_cv=1, skipping.	| completed in 37.0m 18.9s |
# |key='sf_0':value=6.708e-02 	| already computed for i_cv=0, skipping.	| completed in 37.0m 20.0s |
# |key='sf_0':value=6.708e-02 	| already computed for i_cv=1, skipping.	| completed in 37.0m 16.2s |
# |key='sf_0':value=9.212e-02 	| already computed for i_cv=0, skipping.	| completed in 36.0m 55.0s |
# |key='sf_0':value=9.212e-02 	| already computed for i_cv=1, skipping.	| completed in 37.0m 6.2s |
# |key='sf_0':value=1.265e-01 	| already computed for i_cv=0, skipping.	| completed in 37.0m 0.6s |
# |key='sf_0':value=1.265e-01 	| already computed for i_cv=1, skipping.	| completed in 36.0m 51.4s |
# |key='sf_0':value=1.737e-01 	| already computed for i_cv=0, skipping.	| completed in 36.0m 53.2s |
# |key='sf_0':value=1.737e-01 	| already computed for i_cv=1, skipping.	| completed in 36.0m 49.8s |
# |key='sf_0':value=2.386e-01 	| already computed for i_cv=0, skipping.	| completed in 36.0m 56.9s |
# |key='sf_0':value=2.386e-01 	| already computed for i_cv=1, skipping.	| completed in 36.0m 46.9s |
# |key='sf_0':value=3.277e-01 	| already computed for i_cv=0, skipping.	| completed in 36.0m 51.1s |
# |key='sf_0':value=3.277e-01 	| already computed for i_cv=1, skipping.	| completed in 36.0m 51.1s |
# |key='sf_0':value=4.500e-01 	| already computed for i_cv=0, skipping.	| completed in 36.0m 47.1s |
# |key='sf_0':value=4.500e-01 	| already computed for i_cv=1, skipping.	| completed in 36.0m 49.0s |
# --------------------------------------------------
# scanning key='B_sf'
# --------------------------------------------------
# |key='B_sf':value=1.000e-02 	| already computed for i_cv=0, skipping.	| completed in 41.0m 57.9s |
# |key='B_sf':value=1.000e-02 	| already computed for i_cv=1, skipping.	| completed in 41.0m 18.2s |
# |key='B_sf':value=1.373e-02 	| already computed for i_cv=0, skipping.	| completed in 41.0m 18.6s |
# |key='B_sf':value=1.373e-02 	| already computed for i_cv=1, skipping.	| completed in 41.0m 19.4s |
# |key='B_sf':value=1.886e-02 	| already computed for i_cv=0, skipping.	| completed in 41.0m 19.0s |
# |key='B_sf':value=1.886e-02 	| already computed for i_cv=1, skipping.	| completed in 41.0m 19.8s |
# |key='B_sf':value=2.590e-02 	| already computed for i_cv=0, skipping.	| completed in 41.0m 2.6s |
# |key='B_sf':value=2.590e-02 	| already computed for i_cv=1, skipping.	| completed in 41.0m 4.7s |
# |key='B_sf':value=3.557e-02 	| already computed for i_cv=0, skipping.	| completed in 41.0m 18.8s |
# |key='B_sf':value=3.557e-02 	| already computed for i_cv=1, skipping.	| completed in 41.0m 15.5s |
# |key='B_sf':value=4.885e-02 	| already computed for i_cv=0, skipping.	| completed in 41.0m 17.4s |
# |key='B_sf':value=4.885e-02 	| already computed for i_cv=1, skipping.	| completed in 41.0m 16.9s |
# |key='B_sf':value=6.708e-02 	| already computed for i_cv=0, skipping.	| completed in 41.0m 8.6s |
# |key='B_sf':value=6.708e-02 	| already computed for i_cv=1, skipping.	| completed in 41.0m 10.5s |
# |key='B_sf':value=9.212e-02 	| already computed for i_cv=0, skipping.	| completed in 41.0m 16.6s |
# |key='B_sf':value=9.212e-02 	| already computed for i_cv=1, skipping.	| completed in 41.0m 17.5s |
# |key='B_sf':value=1.265e-01 	| already computed for i_cv=0, skipping.	| completed in 40.0m 56.3s |
# |key='B_sf':value=1.265e-01 	| already computed for i_cv=1, skipping.	| completed in 40.0m 50.6s |
# |key='B_sf':value=1.737e-01 	| already computed for i_cv=0, skipping.	| completed in 40.0m 50.6s |
# |key='B_sf':value=1.737e-01 	| already computed for i_cv=1, skipping.	| completed in 40.0m 55.3s |
# |key='B_sf':value=2.386e-01 	| already computed for i_cv=0, skipping.	| completed in 40.0m 55.3s |
# |key='B_sf':value=2.386e-01 	| already computed for i_cv=1, skipping.	| completed in 40.0m 51.6s |
# |key='B_sf':value=3.277e-01 	| already computed for i_cv=0, skipping.	| completed in 40.0m 54.2s |
# |key='B_sf':value=3.277e-01 	| already computed for i_cv=1, skipping.	| completed in 40.0m 48.7s |
# |key='B_sf':value=4.500e-01 	| already computed for i_cv=0, skipping.	| completed in 40.0m 54.6s |
# |key='B_sf':value=4.500e-01 	| already computed for i_cv=1, skipping.	| completed in 40.0m 53.7s |
# --------------------------------------------------
# scanning key='B_theta'
# --------------------------------------------------
# |key='B_theta':value=1.963e-01 	| already computed for i_cv=0, skipping.	| completed in 44.0m 23.5s |
# |key='B_theta':value=1.963e-01 	| already computed for i_cv=1, skipping.	| completed in 40.0m 11.8s |
# |key='B_theta':value=2.335e-01 	| already computed for i_cv=0, skipping.	| completed in 38.0m 26.5s |
# |key='B_theta':value=2.335e-01 	| already computed for i_cv=1, skipping.	| completed in 40.0m 51.2s |
# |key='B_theta':value=2.777e-01 	| already computed for i_cv=0, skipping.	| completed in 39.0m 16.5s |
# |key='B_theta':value=2.777e-01 	| already computed for i_cv=1, skipping.	| completed in 39.0m 56.0s |
# |key='B_theta':value=3.302e-01 	| already computed for i_cv=0, skipping.	| completed in 37.0m 34.7s |
# |key='B_theta':value=3.302e-01 	| already computed for i_cv=1, skipping.	| completed in 37.0m 35.5s |
# |key='B_theta':value=3.927e-01 	| already computed for i_cv=0, skipping.	| completed in 39.0m 51.8s |
# |key='B_theta':value=3.927e-01 	| already computed for i_cv=1, skipping.	| completed in 43.0m 24.2s |
# |key='B_theta':value=4.670e-01 	| already computed for i_cv=0, skipping.	| completed in 39.0m 9.1s |
# |key='B_theta':value=4.670e-01 	| already computed for i_cv=1, skipping.	| completed in 37.0m 24.8s |
# |key='B_theta':value=5.554e-01 	| already computed for i_cv=0, skipping.	| completed in 38.0m 40.1s |
# |key='B_theta':value=5.554e-01 	| already computed for i_cv=1, skipping.	| completed in 38.0m 42.8s |
# |key='B_theta':value=6.604e-01 	| already computed for i_cv=0, skipping.	| completed in 38.0m 56.5s |
# |key='B_theta':value=6.604e-01 	| already computed for i_cv=1, skipping.	| completed in 37.0m 27.3s |
# |key='B_theta':value=7.854e-01 	| already computed for i_cv=0, skipping.	| completed in 38.0m 47.5s |
# |key='B_theta':value=7.854e-01 	| already computed for i_cv=1, skipping.	| completed in 38.0m 5.2s |
# |key='B_theta':value=9.340e-01 	| already computed for i_cv=0, skipping.	| completed in 37.0m 6.5s |
# |key='B_theta':value=9.340e-01 	| already computed for i_cv=1, skipping.	| completed in 38.0m 41.0s |
# |key='B_theta':value=1.111e+00 	| already computed for i_cv=0, skipping.	| completed in 37.0m 27.4s |
# |key='B_theta':value=1.111e+00 	| already computed for i_cv=1, skipping.	| completed in 37.0m 36.2s |
# |key='B_theta':value=1.321e+00 	| already computed for i_cv=0, skipping.	| completed in 36.0m 45.1s |
# |key='B_theta':value=1.321e+00 	| already computed for i_cv=1, skipping.	| completed in 36.0m 47.1s |
# |key='B_theta':value=1.571e+00 	| already computed for i_cv=0, skipping.	| completed in 36.0m 49.8s |
# |key='B_theta':value=1.571e+00 	| already computed for i_cv=1, skipping.	| completed in 36.0m 52.4s |
# --------------------------------------------------
# scanning key='v'
# --------------------------------------------------
# |key='v':value=1.000e-02 	| already computed for i_cv=0, skipping.	| completed in 39.0m 52.9s |
# |key='v':value=1.000e-02 	| already computed for i_cv=1, skipping.	| completed in 38.0m 36.3s |
# |key='v':value=1.455e-02 	| already computed for i_cv=0, skipping.	| completed in 39.0m 33.7s |
# |key='v':value=1.455e-02 	| already computed for i_cv=1, skipping.	| completed in 38.0m 22.8s |
# |key='v':value=2.117e-02 	| already computed for i_cv=0, skipping.	| completed in 39.0m 48.2s |
# |key='v':value=2.117e-02 	| already computed for i_cv=1, skipping.	| completed in 39.0m 33.5s |
# |key='v':value=3.080e-02 	| already computed for i_cv=0, skipping.	| completed in 38.0m 13.8s |
# |key='v':value=3.080e-02 	| already computed for i_cv=1, skipping.	| completed in 38.0m 47.8s |
# |key='v':value=4.481e-02 	| already computed for i_cv=0, skipping.	| completed in 39.0m 17.0s |
# |key='v':value=4.481e-02 	| already computed for i_cv=1, skipping.	| completed in 39.0m 28.2s |
# |key='v':value=6.520e-02 	| already computed for i_cv=0, skipping.	| completed in 38.0m 51.8s |
# |key='v':value=6.520e-02 	| already computed for i_cv=1, skipping.	| completed in 39.0m 2.7s |
# |key='v':value=9.487e-02 	| already computed for i_cv=0, skipping.	| completed in 39.0m 16.9s |
# |key='v':value=9.487e-02 	| already computed for i_cv=1, skipping.	| completed in 39.0m 0.7s |
# |key='v':value=1.380e-01 	| already computed for i_cv=0, skipping.	| completed in 38.0m 2.3s |
# |key='v':value=1.380e-01 	| already computed for i_cv=1, skipping.	| completed in 39.0m 9.4s |
# |key='v':value=2.008e-01 	| already computed for i_cv=0, skipping.	| completed in 38.0m 6.1s |
# |key='v':value=2.008e-01 	| already computed for i_cv=1, skipping.	| completed in 39.0m 16.1s |
# |key='v':value=2.922e-01 	| already computed for i_cv=0, skipping.	| completed in 39.0m 1.7s |
# |key='v':value=2.922e-01 	| already computed for i_cv=1, skipping.	| completed in 38.0m 51.2s |
# |key='v':value=4.251e-01 	| already computed for i_cv=0, skipping.	| completed in 39.0m 40.4s |
# |key='v':value=4.251e-01 	| already computed for i_cv=1, skipping.	| completed in 38.0m 44.0s |
# |key='v':value=6.186e-01 	| already computed for i_cv=0, skipping.	| completed in 39.0m 0.9s |
# |key='v':value=6.186e-01 	| already computed for i_cv=1, skipping.	| completed in 38.0m 17.7s |
# |key='v':value=9.000e-01 	| already computed for i_cv=0, skipping.	| completed in 39.0m 27.9s |
# |key='v':value=9.000e-01 	| already computed for i_cv=1, skipping.	| completed in 39.0m 22.0s |
# --------------------------------------------------
# scanning key='B_V'
# --------------------------------------------------
# |key='B_V':value=1.000e-02 	| already computed for i_cv=0, skipping.	| completed in 37.0m 11.5s |
# |key='B_V':value=1.000e-02 	| already computed for i_cv=1, skipping.	| completed in 36.0m 58.2s |
# |key='B_V':value=1.373e-02 	| already computed for i_cv=0, skipping.	| completed in 37.0m 35.5s |
# |key='B_V':value=1.373e-02 	| already computed for i_cv=1, skipping.	| completed in 38.0m 32.3s |
# |key='B_V':value=1.886e-02 	| already computed for i_cv=0, skipping.	| completed in 38.0m 25.0s |
# |key='B_V':value=1.886e-02 	| already computed for i_cv=1, skipping.	| completed in 38.0m 24.1s |
# |key='B_V':value=2.590e-02 	| already computed for i_cv=0, skipping.	| completed in 39.0m 50.1s |
# |key='B_V':value=2.590e-02 	| already computed for i_cv=1, skipping.	| completed in 39.0m 8.0s |
# |key='B_V':value=3.557e-02 	| already computed for i_cv=0, skipping.	| completed in 37.0m 43.6s |
# |key='B_V':value=3.557e-02 	| already computed for i_cv=1, skipping.	| completed in 37.0m 38.2s |
# |key='B_V':value=4.885e-02 	| already computed for i_cv=0, skipping.	| completed in 37.0m 39.5s |
# |key='B_V':value=4.885e-02 	| already computed for i_cv=1, skipping.	| completed in 37.0m 33.1s |
# |key='B_V':value=6.708e-02 	| already computed for i_cv=0, skipping.	| completed in 37.0m 18.6s |
# |key='B_V':value=6.708e-02 	| already computed for i_cv=1, skipping.	| completed in 37.0m 22.3s |
# |key='B_V':value=9.212e-02 	| already computed for i_cv=0, skipping.	| completed in 37.0m 10.9s |
# |key='B_V':value=9.212e-02 	| already computed for i_cv=1, skipping.	| completed in 38.0m 22.1s |
# |key='B_V':value=1.265e-01 	| already computed for i_cv=0, skipping.	| completed in 38.0m 30.2s |
# |key='B_V':value=1.265e-01 	| already computed for i_cv=1, skipping.	| completed in 38.0m 54.4s |
# |key='B_V':value=1.737e-01 	| already computed for i_cv=0, skipping.	| completed in 38.0m 34.2s |
# |key='B_V':value=1.737e-01 	| already computed for i_cv=1, skipping.	| completed in 38.0m 34.7s |
# |key='B_V':value=2.386e-01 	| already computed for i_cv=0, skipping.	| completed in 38.0m 23.3s |
# |key='B_V':value=2.386e-01 	| already computed for i_cv=1, skipping.	| completed in 38.0m 26.2s |
# |key='B_V':value=3.277e-01 	| already computed for i_cv=0, skipping.	| completed in 38.0m 18.6s |
# |key='B_V':value=3.277e-01 	| already computed for i_cv=1, skipping.	| completed in 38.0m 20.9s |
# |key='B_V':value=4.500e-01 	| already computed for i_cv=0, skipping.	| completed in 38.0m 39.0s |
# |key='B_V':value=4.500e-01 	| already computed for i_cv=1, skipping.	| completed in 38.0m 21.7s |
# --------------------------------------------------
# scanning key='movie_gain'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-07-11_TW_scan_movie_gain.json')...
#     movie_gain  i_cv      loss         time
# 0     5.000000     0  0.000000  3615.902696
# 1     5.000000     1  0.054991  3713.373084
# 2     5.297315     0  0.000000  3736.046556
# 3     5.297315     1  0.000000  3712.345639
# 4     5.612310     0  0.000075  3664.419566
# 5     5.612310     1  0.000000  3834.005453
# 6     5.946036     0  0.000000  4188.673092
# 7     5.946036     1  0.000000  3412.687353
# 8     6.299605     0  0.000000  3395.640254
# 9     6.299605     1  0.000061  3985.602704
# 10    6.674199     0  0.000053  3807.229979
# 11    6.674199     1  0.000103  3863.737304
# 12    7.071068     0  0.000266  3802.784272
# 13    7.071068     1  0.000091  3853.249768
# 14    7.491535     0  0.000609  3292.219831
# 15    7.491535     1  0.000421  3164.643614
# 16    7.937005     0  0.000700  3325.629122
# 17    7.937005     1  0.001483  3236.875344
# 18    8.408964     0  0.002459  3405.871819
# 19    8.408964     1  0.002208  3473.062480
# 20    8.908987     0  0.004684  3553.423208
# 21    8.908987     1  0.004258  3540.506984
# 22    9.438743     0  0.009103  3581.718724
# 23    9.438743     1  0.009261  3472.550058
# 24   10.000000     0  0.018289  3421.780883
# 25   10.000000     1  0.019475  3368.557340
# Saving as ../figures/scan_TW_movie_gain.pdf
# Saving as ../figures/scan_TW_movie_gain.png
# Saving as ../figures/scan_TW_movie_gain.svg
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# --------------------------------------------------
# scanning key='sf_0'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-07-11_TW_scan_sf_0.json')...
#         sf_0  i_cv      loss         time
# 0   0.010000     0  0.109717  2341.905491
# 1   0.010000     1  0.194516  2345.034194
# 2   0.013733     0  0.292418  2335.943326
# 3   0.013733     1  0.321824  2348.926795
# 4   0.018860     0  0.316798  2347.589336
# 5   0.018860     1  0.243941  2333.348115
# 6   0.025900     0  0.237954  2345.633605
# 7   0.025900     1  0.212630  2325.564776
# 8   0.035569     0  0.156790  2323.387728
# 9   0.035569     1  0.083098  2256.216782
# 10  0.048847     0  0.105581  2248.758538
# 11  0.048847     1  0.293700  2238.856538
# 12  0.067082     0  0.239384  2239.974572
# 13  0.067082     1  0.240804  2236.158568
# 14  0.092124     0  0.146980  2215.045197
# 15  0.092124     1  0.315661  2226.233567
# 16  0.126515     0  0.267251  2220.641841
# 17  0.126515     1  0.168096  2211.416363
# 18  0.173744     0  0.191231  2213.231639
# 19  0.173744     1  0.150713  2209.791569
# 20  0.238604     0  0.239472  2216.906979
# 21  0.238604     1  0.333579  2206.882911
# 22  0.327676     0  0.178070  2211.086879
# 23  0.327676     1  0.220976  2211.076339
# 24  0.450000     0  0.194346  2207.090130
# 25  0.450000     1  0.169879  2209.037908
# Saving as ../figures/scan_TW_sf_0.pdf
# Saving as ../figures/scan_TW_sf_0.png
# Saving as ../figures/scan_TW_sf_0.svg
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# --------------------------------------------------
# scanning key='B_sf'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-07-11_TW_scan_B_sf.json')...
#         B_sf  i_cv      loss         time
# 0   0.010000     0  0.161362  2517.882958
# 1   0.010000     1  0.028955  2478.173079
# 2   0.013733     0  0.332353  2478.598823
# 3   0.013733     1  0.237519  2479.399045
# 4   0.018860     0  0.183413  2478.973652
# 5   0.018860     1  0.180654  2479.751255
# 6   0.025900     0  0.128160  2462.554265
# 7   0.025900     1  0.191400  2464.659939
# 8   0.035569     0  0.269973  2478.798611
# 9   0.035569     1  0.174635  2475.524727
# 10  0.048847     0  0.271624  2477.434419
# 11  0.048847     1  0.207457  2476.928745
# 12  0.067082     0  0.247702  2468.643882
# 13  0.067082     1  0.223295  2470.539242
# 14  0.092124     0  0.100949  2476.639594
# 15  0.092124     1  0.315277  2477.495669
# 16  0.126515     0  0.235574  2456.283436
# 17  0.126515     1  0.263281  2450.575713
# 18  0.173744     0  0.235470  2450.601383
# 19  0.173744     1  0.201689  2455.319324
# 20  0.238604     0  0.229635  2455.335011
# 21  0.238604     1  0.274737  2451.646292
# 22  0.327676     0  0.354743  2454.200170
# 23  0.327676     1  0.145257  2448.741262
# 24  0.450000     0  0.288483  2454.600454
# 25  0.450000     1  0.357539  2453.685312
# Saving as ../figures/scan_TW_B_sf.pdf
# Saving as ../figures/scan_TW_B_sf.png
# Saving as ../figures/scan_TW_B_sf.svg
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# --------------------------------------------------
# scanning key='B_theta'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-07-11_TW_scan_B_theta.json')...
#      B_theta  i_cv      loss         time
# 0   0.196350     0  0.245852  2663.484135
# 1   0.196350     1  0.358478  2411.794817
# 2   0.233500     0  0.275404  2306.515930
# 3   0.233500     1  0.271791  2451.176327
# 4   0.277680     0  0.175568  2356.528725
# 5   0.277680     1  0.111179  2396.000755
# 6   0.330219     0  0.203530  2254.671295
# 7   0.330219     1  0.242571  2255.459811
# 8   0.392699     0  0.243967  2391.767129
# 9   0.392699     1  0.158085  2604.211089
# 10  0.467001     0  0.197983  2349.127512
# 11  0.467001     1  0.279267  2244.814693
# 12  0.555360     0  0.150015  2320.115016
# 13  0.555360     1  0.120792  2322.772529
# 14  0.660439     0  0.220086  2336.522198
# 15  0.660439     1  0.272671  2247.296224
# 16  0.785398     0  0.219944  2327.456342
# 17  0.785398     1  0.175701  2285.190974
# 18  0.934001     0  0.074955  2226.450959
# 19  0.934001     1  0.276613  2321.029742
# 20  1.110721     0  0.180018  2247.416467
# 21  1.110721     1  0.295947  2256.162389
# 22  1.320877     0  0.274387  2205.141727
# 23  1.320877     1  0.179702  2207.127187
# 24  1.570796     0  0.129844  2209.789454
# 25  1.570796     1  0.367089  2212.440445
# Saving as ../figures/scan_TW_B_theta.pdf
# Saving as ../figures/scan_TW_B_theta.png
# Saving as ../figures/scan_TW_B_theta.svg
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# --------------------------------------------------
# scanning key='v'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-07-11_TW_scan_v.json')...
#            v  i_cv      loss         time
# 0   0.010000     0  0.310685  2392.942201
# 1   0.010000     1  0.179292  2316.324988
# 2   0.014550     0  0.166560  2373.653023
# 3   0.014550     1  0.339696  2302.824607
# 4   0.021169     0  0.266960  2388.192786
# 5   0.021169     1  0.284354  2373.489514
# 6   0.030801     0  0.300994  2293.826823
# 7   0.030801     1  0.278166  2327.774255
# 8   0.044814     0  0.211588  2357.011006
# 9   0.044814     1  0.153756  2368.192470
# 10  0.065203     0  0.219409  2331.763705
# 11  0.065203     1  0.252871  2342.693066
# 12  0.094868     0  0.199452  2356.923811
# 13  0.094868     1  0.317788  2340.672405
# 14  0.138030     0  0.254384  2282.280290
# 15  0.138030     1  0.296344  2349.373181
# 16  0.200830     0  0.272442  2286.086612
# 17  0.200830     1  0.235588  2356.134124
# 18  0.292201     0  0.229044  2341.685796
# 19  0.292201     1  0.224159  2331.214672
# 20  0.425143     0  0.230435  2380.402445
# 21  0.425143     1  0.241553  2324.000750
# 22  0.618570     0  0.271903  2340.854747
# 23  0.618570     1  0.175069  2297.707564
# 24  0.900000     0  0.254739  2367.880088
# 25  0.900000     1  0.285624  2362.045657
# Saving as ../figures/scan_TW_v.pdf
# Saving as ../figures/scan_TW_v.png
# Saving as ../figures/scan_TW_v.svg
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# --------------------------------------------------
# scanning key='B_V'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-07-11_TW_scan_B_V.json')...
#          B_V  i_cv      loss         time
# 0   0.010000     0  0.176225  2231.524822
# 1   0.010000     1  0.103610  2218.246394
# 2   0.013733     0  0.289202  2255.461204
# 3   0.013733     1  0.129446  2312.276422
# 4   0.018860     0  0.217710  2305.015358
# 5   0.018860     1  0.088477  2304.067421
# 6   0.025900     0  0.193900  2390.072165
# 7   0.025900     1  0.212429  2348.044444
# 8   0.035569     0  0.171362  2263.571855
# 9   0.035569     1  0.222322  2258.246286
# 10  0.048847     0  0.167785  2259.535109
# 11  0.048847     1  0.282297  2253.074920
# 12  0.067082     0  0.318093  2238.645217
# 13  0.067082     1  0.236664  2242.312570
# 14  0.092124     0  0.247344  2230.940165
# 15  0.092124     1  0.189767  2302.146193
# 16  0.126515     0  0.216123  2310.220445
# 17  0.126515     1  0.181606  2334.422520
# 18  0.173744     0  0.189665  2314.181223
# 19  0.173744     1  0.273414  2314.690900
# 20  0.238604     0  0.177462  2303.331550
# 21  0.238604     1  0.201624  2306.234772
# 22  0.327676     0  0.216669  2298.618935
# 23  0.327676     1  0.281599  2300.907916
# 24  0.450000     0  0.209337  2319.007030
# 25  0.450000     1  0.249433  2301.688293
# Saving as ../figures/scan_TW_B_V.pdf
# Saving as ../figures/scan_TW_B_V.png
# Saving as ../figures/scan_TW_B_V.svg
# Bbox(x0=0.125, y0=0.25, x1=0.95, y1=0.975)
# ✅ END: 2026-07-29 17:46:12

# %%
# pprint("🚀 Running: 34_MNESIS_learn-Lorenz-attractor.ipynb")
# print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 34_MNESIS_learn-Lorenz-attractor.ipynb
# print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# pprint("🚀 Running: 40_MNESIS_learn-SHD.ipynb")
# print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 40_MNESIS_learn-SHD.ipynb
# print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("✅ All MNESIS notebooks executed successfully!")
# Out:
# =============================================
# ✅ All MNESIS notebooks executed successfully!
# =============================================
