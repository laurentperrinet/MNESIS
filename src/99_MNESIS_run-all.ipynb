# %% [markdown]
# # MNESIS : a notebook that runs all of them

# %%
# %pip install -U -r requirements.txt
# Out:
# Requirement already satisfied: pip in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (26.2.1)
# Requirement already satisfied: torch in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (2.11.0)
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting torch (from -r requirements.txt (line 5))
#   Downloading torch-2.13.0-cp312-cp312-macosx_14_0_arm64.whl.metadata (39 kB)
# Requirement already satisfied: torchvision in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (0.26.0)
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting torchvision (from -r requirements.txt (line 6))
#   Downloading torchvision-0.28.0-cp312-cp312-macosx_14_0_arm64.whl.metadata (5.6 kB)
# Requirement already satisfied: snntorch in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (0.9.4)
# Collecting snntorch (from -r requirements.txt (line 7))
#   Downloading snntorch-1.0.0-py2.py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: optuna in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (4.8.0)
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting optuna (from -r requirements.txt (line 8))
#   Using cached optuna-4.9.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: ipykernel in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (7.2.0)
# Collecting ipykernel (from -r requirements.txt (line 9))
#   Using cached ipykernel-7.3.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: matplotlib in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (3.10.9)
# Collecting matplotlib (from -r requirements.txt (line 10))
#   Downloading matplotlib-3.11.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (80 kB)
# Requirement already satisfied: seaborn in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (0.13.2)
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting SciencePlots (from -r requirements.txt (line 12))
#   Downloading scienceplots-2.2.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (2.4.4)
# Collecting numpy (from -r requirements.txt (line 13))
#   Downloading numpy-2.5.2-cp312-cp312-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: pandas in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (3.0.3)
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting pandas (from -r requirements.txt (line 14))
#   Downloading pandas-3.0.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (79 kB)
# Requirement already satisfied: jinja2 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 15)) (3.1.6)
# Requirement already satisfied: prompt-toolkit in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 16)) (3.0.52)
# Collecting prompt-toolkit (from -r requirements.txt (line 16))
#   Using cached prompt_toolkit-3.0.53-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: ipython in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 17)) (9.13.0)
# Collecting ipython (from -r requirements.txt (line 17))
#   Downloading ipython-9.17.1-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: jupyter_server in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 18)) (2.18.2)
# Collecting jupyter_server (from -r requirements.txt (line 18))
#   Downloading jupyter_server-2.21.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: jupyter in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 19)) (1.1.1)
# Requirement already satisfied: jupyterlab-git in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 20)) (0.53.0)
# Collecting jupyterlab-git (from -r requirements.txt (line 20))
#   Downloading jupyterlab_git-0.54.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: jupyter_contrib_nbextensions in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 21)) (0.7.0)
# Requirement already satisfied: nbconvert in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 22)) (7.17.1)
# Requirement already satisfied: jupyterlab in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 23)) (4.5.7)
# Collecting jupyterlab (from -r requirements.txt (line 23))
#   Downloading jupyterlab-4.6.3-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: ipynb in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 24)) (0.5.1)
# Requirement already satisfied: optuna-dashboard in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 26)) (0.20.0)
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# Requirement already satisfied: tqdm in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 27)) (4.67.3)
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting tqdm (from -r requirements.txt (line 27))
#   Downloading tqdm-4.70.0-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: plotly in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 28)) (6.7.0)
# Collecting plotly (from -r requirements.txt (line 28))
#   Downloading plotly-7.0.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: torch_optimizer in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 29)) (0.3.0)
# Requirement already satisfied: scipy in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 30)) (1.17.1)
# Collecting scipy (from -r requirements.txt (line 30))
#   Downloading scipy-1.18.1-cp312-cp312-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: statsmodels in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 31)) (0.14.6)
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting statsmodels (from -r requirements.txt (line 31))
#   Downloading statsmodels-0.15.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Requirement already satisfied: scikit-learn in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 32)) (1.8.0)
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting scikit-learn (from -r requirements.txt (line 32))
#   Downloading scikit_learn-1.9.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: MotionClouds in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 33)) (20220927)
# Requirement already satisfied: h5py in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 34)) (3.16.0)
# Requirement already satisfied: filelock in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 5)) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 5)) (4.15.0)
# Requirement already satisfied: setuptools>=77.0.3 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 5)) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 5)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 5)) (3.6.1)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 5)) (2026.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from torchvision->-r requirements.txt (line 6)) (12.2.0)
# Requirement already satisfied: alembic>=1.5.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from optuna->-r requirements.txt (line 8)) (1.18.4)
# Requirement already satisfied: colorlog in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from optuna->-r requirements.txt (line 8)) (6.10.1)
# Requirement already satisfied: packaging>=20.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from optuna->-r requirements.txt (line 8)) (26.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from optuna->-r requirements.txt (line 8)) (2.0.49)
# Requirement already satisfied: PyYAML in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from optuna->-r requirements.txt (line 8)) (6.0.3)
# Requirement already satisfied: appnope>=0.1.2 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from ipykernel->-r requirements.txt (line 9)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from ipykernel->-r requirements.txt (line 9)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from ipykernel->-r requirements.txt (line 9)) (1.8.20)
# Collecting jupyter-client>=8.9.0 (from ipykernel->-r requirements.txt (line 9))
#   Downloading jupyter_client-8.10.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from ipykernel->-r requirements.txt (line 9)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from ipykernel->-r requirements.txt (line 9)) (0.2.1)
# Collecting nest-asyncio2>=1.7.0 (from ipykernel->-r requirements.txt (line 9))
#   Using cached nest_asyncio2-1.7.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: psutil>=5.7 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from ipykernel->-r requirements.txt (line 9)) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from ipykernel->-r requirements.txt (line 9)) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from ipykernel->-r requirements.txt (line 9)) (6.5.5)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from ipykernel->-r requirements.txt (line 9)) (5.14.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 10)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 10)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 10)) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 10)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 10)) (2.9.0.post0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jinja2->-r requirements.txt (line 15)) (3.0.3)
# Requirement already satisfied: wcwidth>=0.1.4 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from prompt-toolkit->-r requirements.txt (line 16)) (0.6.0)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from ipython->-r requirements.txt (line 17)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from ipython->-r requirements.txt (line 17)) (0.19.2)
# Requirement already satisfied: pexpect>4.6 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from ipython->-r requirements.txt (line 17)) (4.9.0)
# Requirement already satisfied: pygments>=2.14.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from ipython->-r requirements.txt (line 17)) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from ipython->-r requirements.txt (line 17)) (0.6.3)
# Requirement already satisfied: anyio>=3.1.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyter_server->-r requirements.txt (line 18)) (4.13.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyter_server->-r requirements.txt (line 18)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyter_server->-r requirements.txt (line 18)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyter_server->-r requirements.txt (line 18)) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyter_server->-r requirements.txt (line 18)) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyter_server->-r requirements.txt (line 18)) (0.25.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyter_server->-r requirements.txt (line 18)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyter_server->-r requirements.txt (line 18)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyter_server->-r requirements.txt (line 18)) (1.9.0)
# Requirement already satisfied: notebook in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyter->-r requirements.txt (line 19)) (7.5.5)
# Requirement already satisfied: jupyter-console in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyter->-r requirements.txt (line 19)) (6.6.3)
# Requirement already satisfied: ipywidgets in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyter->-r requirements.txt (line 19)) (8.1.8)
# Requirement already satisfied: jupyterlab-git-core>=0.52.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyterlab-git-core[nbdime]>=0.52.0->jupyterlab-git->-r requirements.txt (line 20)) (0.53.0)
# Requirement already satisfied: ipython_genutils in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 21)) (0.2.0)
# Requirement already satisfied: jupyter_contrib_core>=0.3.3 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 21)) (0.4.2)
# Requirement already satisfied: jupyter_highlight_selected_word>=0.1.1 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 21)) (0.2.0)
# Requirement already satisfied: jupyter_nbextensions_configurator>=0.4.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 21)) (0.6.4)
# Requirement already satisfied: lxml in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 21)) (6.0.4)
# Requirement already satisfied: beautifulsoup4 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from nbconvert->-r requirements.txt (line 22)) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->-r requirements.txt (line 22)) (6.3.0)
# Requirement already satisfied: defusedxml in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from nbconvert->-r requirements.txt (line 22)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from nbconvert->-r requirements.txt (line 22)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from nbconvert->-r requirements.txt (line 22)) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from nbconvert->-r requirements.txt (line 22)) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from nbconvert->-r requirements.txt (line 22)) (1.5.1)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyterlab->-r requirements.txt (line 23)) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyterlab->-r requirements.txt (line 23)) (0.28.1)
# Collecting jupyter-builder>=1.0.2 (from jupyterlab->-r requirements.txt (line 23))
#   Downloading jupyter_builder-1.2.2-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyterlab->-r requirements.txt (line 23)) (2.3.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyterlab->-r requirements.txt (line 23)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyterlab->-r requirements.txt (line 23)) (0.2.4)
# Requirement already satisfied: certifi in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 23)) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 23)) (1.0.9)
# Requirement already satisfied: idna in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 23)) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 23)) (0.16.0)
# Requirement already satisfied: babel>=2.10 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 23)) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 23)) (0.14.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 23)) (4.26.0)
# Requirement already satisfied: requests>=2.31 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 23)) (2.33.1)
# Requirement already satisfied: bottle>=0.13.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from optuna-dashboard->-r requirements.txt (line 26)) (0.13.4)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from plotly->-r requirements.txt (line 28)) (2.19.0)
# Requirement already satisfied: pytorch-ranger>=0.1.1 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from torch_optimizer->-r requirements.txt (line 29)) (0.1.1)
# Requirement already satisfied: patsy>=0.5.6 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from statsmodels->-r requirements.txt (line 31)) (1.0.2)
# Collecting formulaic>=1.1.0 (from statsmodels->-r requirements.txt (line 31))
#   Downloading formulaic-1.2.2-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: joblib>=1.4.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from scikit-learn->-r requirements.txt (line 32)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from scikit-learn->-r requirements.txt (line 32)) (3.6.0)
# Requirement already satisfied: Mako in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from alembic>=1.5.0->optuna->-r requirements.txt (line 8)) (1.3.11)
# Requirement already satisfied: argon2-cffi-bindings in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter_server->-r requirements.txt (line 18)) (25.1.0)
# Requirement already satisfied: webencodings in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->-r requirements.txt (line 22)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->-r requirements.txt (line 22)) (1.4.0)
# Collecting interface-meta>=1.2.0 (from formulaic>=1.1.0->statsmodels->-r requirements.txt (line 31))
#   Downloading interface_meta-2.0.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting wrapt>=1.0 (from formulaic>=1.1.0->statsmodels->-r requirements.txt (line 31))
#   Downloading wrapt-2.4.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jedi>=0.18.2->ipython->-r requirements.txt (line 17)) (0.8.6)
# Requirement already satisfied: attrs>=22.2.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 23)) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 23)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 23)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 23)) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->-r requirements.txt (line 9)) (4.9.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter_server->-r requirements.txt (line 18)) (4.1.0)
# Requirement already satisfied: rfc3339-validator in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter_server->-r requirements.txt (line 18)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter_server->-r requirements.txt (line 18)) (0.1.1)
# Requirement already satisfied: fqdn in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter_server->-r requirements.txt (line 18)) (1.5.1)
# Requirement already satisfied: isoduration in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter_server->-r requirements.txt (line 18)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter_server->-r requirements.txt (line 18)) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter_server->-r requirements.txt (line 18)) (1.1.0)
# Requirement already satisfied: uri-template in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter_server->-r requirements.txt (line 18)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter_server->-r requirements.txt (line 18)) (25.10.0)
# Requirement already satisfied: nbdime~=4.0.1 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from jupyterlab-git-core[nbdime]>=0.52.0->jupyterlab-git->-r requirements.txt (line 20)) (4.0.4)
# Requirement already satisfied: colorama in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from nbdime~=4.0.1->jupyterlab-git-core[nbdime]>=0.52.0->jupyterlab-git->-r requirements.txt (line 20)) (0.4.6)
# Requirement already satisfied: gitpython!=2.1.4,!=2.1.5,!=2.1.6 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from nbdime~=4.0.1->jupyterlab-git-core[nbdime]>=0.52.0->jupyterlab-git->-r requirements.txt (line 20)) (3.1.46)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from gitpython!=2.1.4,!=2.1.5,!=2.1.6->nbdime~=4.0.1->jupyterlab-git-core[nbdime]>=0.52.0->jupyterlab-git->-r requirements.txt (line 20)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=2.1.4,!=2.1.5,!=2.1.6->nbdime~=4.0.1->jupyterlab-git-core[nbdime]>=0.52.0->jupyterlab-git->-r requirements.txt (line 20)) (5.0.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter_server->-r requirements.txt (line 18)) (2.21.2)
# Collecting jupyterlab (from -r requirements.txt (line 23))
#   Downloading jupyterlab-4.5.10-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from pexpect>4.6->ipython->-r requirements.txt (line 17)) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 10)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 23)) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 23)) (2.6.3)
# Requirement already satisfied: lark>=1.2.2 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter_server->-r requirements.txt (line 18)) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython->-r requirements.txt (line 17)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython->-r requirements.txt (line 17)) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython->-r requirements.txt (line 17)) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter_server->-r requirements.txt (line 18)) (2.0.0)
# Requirement already satisfied: pycparser in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter_server->-r requirements.txt (line 18)) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->-r requirements.txt (line 22)) (2.8.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 19)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 19)) (3.0.16)
# Requirement already satisfied: arrow>=0.15.0 in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter_server->-r requirements.txt (line 18)) (1.4.0)
# Requirement already satisfied: tzdata in /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter_server->-r requirements.txt (line 18)) (2026.1)
# Downloading torch-2.13.0-cp312-cp312-macosx_14_0_arm64.whl (111.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.2/111.2 MB 98.5 MB/s  0:00:01m0:00:0100:01
# Downloading torchvision-0.28.0-cp312-cp312-macosx_14_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 63.8 MB/s  0:00:00
# Downloading snntorch-1.0.0-py2.py3-none-any.whl (133 kB)
# Using cached optuna-4.9.0-py3-none-any.whl (425 kB)
# Using cached ipykernel-7.3.0-py3-none-any.whl (120 kB)
# Downloading matplotlib-3.11.1-cp312-cp312-macosx_11_0_arm64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 103.1 MB/s  0:00:00
# Downloading scienceplots-2.2.2-py3-none-any.whl (33 kB)
# Downloading numpy-2.5.2-cp312-cp312-macosx_14_0_arm64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 93.8 MB/s  0:00:00
# Downloading pandas-3.0.5-cp312-cp312-macosx_11_0_arm64.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 104.7 MB/s  0:00:00
# Using cached prompt_toolkit-3.0.53-py3-none-any.whl (392 kB)
# Downloading ipython-9.17.1-py3-none-any.whl (639 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 639.0/639.0 kB 40.2 MB/s  0:00:00
# Downloading jupyter_server-2.21.0-py3-none-any.whl (393 kB)
# Downloading jupyterlab_git-0.54.1-py3-none-any.whl (11 kB)
# Downloading tqdm-4.70.0-py3-none-any.whl (80 kB)
# Downloading plotly-7.0.0-py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 101.9 MB/s  0:00:00
# Downloading scipy-1.18.1-cp312-cp312-macosx_14_0_arm64.whl (20.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 110.0 MB/s  0:00:00
# Downloading statsmodels-0.15.0-cp312-cp312-macosx_11_0_arm64.whl (11.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 103.7 MB/s  0:00:00
# Downloading scikit_learn-1.9.0-cp312-cp312-macosx_12_0_arm64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 101.9 MB/s  0:00:00
# Downloading formulaic-1.2.2-py3-none-any.whl (118 kB)
# Downloading interface_meta-2.0.1-py3-none-any.whl (15 kB)
# Downloading jupyter_client-8.10.0-py3-none-any.whl (110 kB)
# Using cached nest_asyncio2-1.7.2-py3-none-any.whl (7.8 kB)
# Downloading jupyterlab-4.5.10-py3-none-any.whl (12.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 107.0 MB/s  0:00:00
# Downloading wrapt-2.4.0-cp312-cp312-macosx_11_0_arm64.whl (96 kB)
# Installing collected packages: wrapt, tqdm, snntorch, prompt-toolkit, plotly, numpy, nest-asyncio2, interface-meta, torch, scipy, pandas, jupyter-client, ipython, torchvision, scikit-learn, optuna, matplotlib, ipykernel, formulaic, statsmodels, SciencePlots, jupyter_server, jupyterlab, jupyterlab-git
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.3
#     Uninstalling tqdm-4.67.3:
#       Successfully uninstalled tqdm-4.67.3
#   Attempting uninstall: snntorch
#     Found existing installation: snntorch 0.9.4
#     Uninstalling snntorch-0.9.4:
#       Successfully uninstalled snntorch-0.9.4
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt_toolkit 3.0.52
#     Uninstalling prompt_toolkit-3.0.52:
#       Successfully uninstalled prompt_toolkit-3.0.52
#   Attempting uninstall: plotly0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/24 [prompt-toolkit]
#     Found existing installation: plotly 6.7.0━━━━━━━━━━━━━━━━━  3/24 [prompt-toolkit]
#     Uninstalling plotly-6.7.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/24 [prompt-toolkit]
#       Successfully uninstalled plotly-6.7.0━━━━━━━━━━━━━━━━━━━━━━━  4/24 [plotly]kit]
#   Attempting uninstall: numpy━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/24 [plotly]
#     Found existing installation: numpy 2.4.4━━━━━━━━━━━━━━━━━━  4/24 [plotly]
#     Uninstalling numpy-2.4.4:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/24 [plotly]
#       Successfully uninstalled numpy-2.4.4━━━━━━━━━━━━━━━━━━━━  4/24 [plotly]
#   Attempting uninstall: torchm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/24 [numpy]
#     Found existing installation: torch 2.11.0━━━━━━━━━━━━━━━━━  5/24 [numpy]
#     Uninstalling torch-2.11.0:╺━━━━━━━━━━━━━━━━━━━━━━━━━━  8/24 [torch]
#       Successfully uninstalled torch-2.11.0━━━━━━━━━━━━━━━━━━━  8/24 [torch]
#   Attempting uninstall: scipym╺━━━━━━━━━━━━━━━━━━━━━━━━━━  8/24 [torch]
#     Found existing installation: scipy 1.17.1━━━━━━━━━━━━━━━━━  8/24 [torch]
#     Uninstalling scipy-1.17.1:m━━━━━━━━━━━━━━━━━━━━━━━━━━  8/24 [torch]
#       Successfully uninstalled scipy-1.17.1━━━━━━━━━━━━━━━━━━━  8/24 [torch]
#   Attempting uninstall: pandas0m╺━━━━━━━━━━━━━━━━━━━━━━━━  9/24 [scipy]
#     Found existing installation: pandas 3.0.3━━━━━━━━━━━━━━━━━  9/24 [scipy]
#     Uninstalling pandas-3.0.3:91m╸━━━━━━━━━━━━━━━━━━━━━━━ 10/24 [pandas]
#       Successfully uninstalled pandas-3.0.3━━━━━━━━━━━━━━━━━━━ 10/24 [pandas]
#   Attempting uninstall: jupyter-client━━━━━━━━━━━━━━━━━━━━━━━ 10/24 [pandas]
#     Found existing installation: jupyter_client 8.8.0━━━━━━━━━ 10/24 [pandas]
#     Uninstalling jupyter_client-8.8.0:m━━━━━━━━━━━━━━━━━━━━━━━ 10/24 [pandas]
#       Successfully uninstalled jupyter_client-8.8.0━━━━━━━━━━━ 10/24 [pandas]
#   Attempting uninstall: ipython╺━━━━━━━━━━━━━━━━━━━━━ 11/24 [jupyter-client]
#     Found existing installation: ipython 9.13.0━━━━━━━━━━━━━━━ 11/24 [jupyter-client]
#     Uninstalling ipython-9.13.0:━━━━━━━━━━━━━━━━━━━━━ 11/24 [jupyter-client]
#       Successfully uninstalled ipython-9.13.0━━━━━━━━━━━━━━━━━ 11/24 [jupyter-client]
#   Attempting uninstall: torchvision0m╺━━━━━━━━━━━━━━━━━━━ 12/24 [ipython]nt]
#     Found existing installation: torchvision 0.26.0━━━━━━━━━━━ 12/24 [ipython]
#     Uninstalling torchvision-0.26.0:0m━━━━━━━━━━━━━━━━━━━ 12/24 [ipython]
#       Successfully uninstalled torchvision-0.26.0━━━━━━━━━━━━━ 12/24 [ipython]
#   Attempting uninstall: scikit-learn1m╸━━━━━━━━━━━━━━━━━━ 13/24 [torchvision]
#     Found existing installation: scikit-learn 1.8.0━━━━━━━━━━━ 13/24 [torchvision]
#     Uninstalling scikit-learn-1.8.0:━━━━━━━━━━━━━━━━━━ 13/24 [torchvision]
#       Successfully uninstalled scikit-learn-1.8.0━━━━━━━━━━━━━ 13/24 [torchvision]
#   Attempting uninstall: optuna━╺━━━━━━━━━━━━━━━━ 14/24 [scikit-learn]
#     Found existing installation: optuna 4.8.0m━━━━━━━━━━━━━━━━ 14/24 [scikit-learn]
#     Uninstalling optuna-4.8.0:━━━╺━━━━━━━━━━━━━━ 15/24 [optuna]n]
#       Successfully uninstalled optuna-4.8.0━━━━━━━━━━━━━━ 15/24 [optuna]
#   Attempting uninstall: matplotlib╺━━━━━━━━━━━━━━ 15/24 [optuna]
#     Found existing installation: matplotlib 3.10.9━━━━━━━━━━━━ 15/24 [optuna]
#     Uninstalling matplotlib-3.10.9:90m╺━━━━━━━━━━━━━━ 15/24 [optuna]
#       Successfully uninstalled matplotlib-3.10.9━━━━━━━━━━━━━ 16/24 [matplotlib]
#   Attempting uninstall: ipykernel━╸━━━━━━━━━━━━━ 16/24 [matplotlib]
#     Found existing installation: ipykernel 7.2.0m━━━━━━━━━━━━━ 16/24 [matplotlib]
#     Uninstalling ipykernel-7.2.0:m╸━━━━━━━━━━━━━ 16/24 [matplotlib]
#       Successfully uninstalled ipykernel-7.2.0━━━━━━━━━━━ 17/24 [ipykernel]
#   Attempting uninstall: statsmodelsm╺━━━━━━━━━━━ 17/24 [ipykernel]
#     Found existing installation: statsmodels 0.14.6━━━━━━━━━━━ 17/24 [ipykernel]
#     Uninstalling statsmodels-0.14.6:━━━╸━━━━━━━━ 19/24 [statsmodels]
#       Successfully uninstalled statsmodels-0.14.6━━━━━━━━ 19/24 [statsmodels]
#   Attempting uninstall: jupyter_server━╸━━━━━━━━ 19/24 [statsmodels]
#     Found existing installation: jupyter_server 2.18.2━━━━━━━━ 19/24 [statsmodels]
#     Uninstalling jupyter_server-2.18.2:╸━━━━━━━━ 19/24 [statsmodels]
#       Successfully uninstalled jupyter_server-2.18.20m━━━━━━━━ 19/24 [statsmodels]
#   Attempting uninstall: jupyterlab━━━━━━━━━╺━━━━ 21/24 [jupyter_server]
#     Found existing installation: jupyterlab 4.5.7━━━━ 21/24 [jupyter_server]
#     Uninstalling jupyterlab-4.5.7:━━━━━╺━━━━ 21/24 [jupyter_server]
#       Successfully uninstalled jupyterlab-4.5.7m╺━━━━ 21/24 [jupyter_server]
#   Attempting uninstall: jupyterlab-git━━━━━━╸━━━ 22/24 [jupyterlab]
#     Found existing installation: jupyterlab_git 0.53.0━━━ 22/24 [jupyterlab]
#     Uninstalling jupyterlab_git-0.53.0:━╸━━━ 22/24 [jupyterlab]
#       Successfully uninstalled jupyterlab_git-0.53.00m━━━ 22/24 [jupyterlab]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24/24 [jupyterlab-git]upyterlab]
# Successfully installed SciencePlots-2.2.2 formulaic-1.2.2 interface-meta-2.0.1 ipykernel-7.3.0 ipython-9.17.1 jupyter-client-8.10.0 jupyter_server-2.21.0 jupyterlab-4.5.10 jupyterlab-git-0.54.1 matplotlib-3.11.1 nest-asyncio2-1.7.2 numpy-2.5.2 optuna-4.9.0 pandas-3.0.5 plotly-7.0.0 prompt-toolkit-3.0.53 scikit-learn-1.9.0 scipy-1.18.1 snntorch-1.0.0 statsmodels-0.15.0 torch-2.13.0 torchvision-0.28.0 tqdm-4.70.0 wrapt-2.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from mnesis_boilerplate import datetime, pprint
# Out:
# datetag = '2026-08-06'
# Using device: mps
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages/matplotlib/style/__init__.py:130, in use(style)
#     129 try:
# --> 130     style = rc_params_from_file(style, use_default_template=False)
#     131 except OSError as err:
#
# File ~/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages/matplotlib/__init__.py:968, in rc_params_from_file(fname, fail_on_error, use_default_template)
#     954 """
#     955 Construct a `RcParams` from file *fname*.
#     956
#    (...)    966     parameters specified in the file. (Useful for updating dicts.)
#     967 """
# --> 968 config_from_file = _rc_params_in_file(fname, fail_on_error=fail_on_error)
#     970 if not use_default_template:
#
# File ~/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages/matplotlib/__init__.py:900, in _rc_params_in_file(fname, transform, fail_on_error)
#     899 rc_temp = {}
# --> 900 with _open_file_or_url(fname) as fd:
#     901     try:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.14/Frameworks/Python.framework/Versions/3.12/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File ~/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages/matplotlib/__init__.py:877, in _open_file_or_url(fname)
#     876 fname = os.path.expanduser(fname)
# --> 877 with open(fname, encoding='utf-8') as f:
#     878     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nature'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from mnesis_boilerplate import datetime, pprint
#
# File ~/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/src/mnesis_boilerplate.py:104
#     101 if os.environ.get("USER") == "uvb28bo":
#     102     figpath = None # Jean Zay
# --> 104 plt.style.use(['nature', 'science', 'prl'])   # or 'nature' for a colour figure
#     106 # --- Constants ---
#     107 phi = np.sqrt(5)/2 + 1/2
#
# File ~/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages/matplotlib/style/__init__.py:132, in use(style)
#     130         style = rc_params_from_file(style, use_default_template=False)
#     131     except OSError as err:
# --> 132         raise OSError(
#     133             f"{style!r} is not a valid package style, path of style "
#     134             f"file, URL of style file, or library style name (library "
#     135             f"styles are listed in `style.available`)") from err
#     136 filtered = {}
#     137 for k in style:  # don't trigger RcParams.__getitem__('backend')
#
# OSError: 'nature' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)

# %%
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
pprint("🚀 Importing: mnesis_boilerplate.py")
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 10_MNESIS_generative-model.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 10_MNESIS_generative-model.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 11_MNESIS_learn-synthetic.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 11_MNESIS_learn-synthetic.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 13_MNESIS_testing-inference.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 13_MNESIS_testing-inference.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 14_MNESIS_testing-noise.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 14_MNESIS_testing-noise.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 15_MNESIS_testing-trigger-duration.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 15_MNESIS_testing-trigger-duration.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 16_MNESIS_testing-trigger-fraction.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 16_MNESIS_testing-trigger-fraction.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 20_MNESIS_scanning-parameters.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 20_MNESIS_scanning-parameters.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 25_MNESIS_optuna.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 25_MNESIS_optuna.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 30_MNESIS_learn-periodic.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 30_MNESIS_learn-periodic.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 32_MNESIS_learn-travelling-waves.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 32_MNESIS_learn-travelling-waves.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 34_MNESIS_learn-Lorenz-attractor.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 34_MNESIS_learn-Lorenz-attractor.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 36_MNESIS_learn-text.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 36_MNESIS_learn-text.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# pprint("🚀 Running: 40_MNESIS_learn-SHD.ipynb")
# print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 40_MNESIS_learn-SHD.ipynb
# print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("✅ All MNESIS notebooks executed successfully!")
