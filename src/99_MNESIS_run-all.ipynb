# %% [markdown]
# # MNESIS : a notebook that runs all of them

# %%
import datetime

# %%
# print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 01_MNESIS_boilerplate.ipynb
# pprint("🚀 Running: 01_MNESIS_boilerplate.ipynb")
# print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# datetag = '2026-06-18'
# Using device: mps
# SNNtorch version 0.9.4

# %%
# pprint("🚀 Running: 05_MNESIS_parameters.ipynb")
# print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 05_MNESIS_parameters.ipynb
# print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# pprint("🚀 Running: 08_MNESIS_generative-model.ipynb")
# print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 08_MNESIS_generative-model.ipynb
# print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# pripprintnt("🚀 Running: 10_MNESIS_polychronous-chains.ipynb")
# print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 10_MNESIS_polychronous-chains.ipynb
# print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 11_MNESIS_learn-synthetic.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 11_MNESIS_learn-synthetic.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ==========================================
# 🚀 Running: 11_MNESIS_learn-synthetic.ipynb
# ==========================================
# ⏱️  START: 2026-06-20 09:22:39
# datetag = '2026-06-18'
# Using device: mps
# SNNtorch version 0.9.4
# Spikes in one target 2.6,  in a SM window 0.8
# for a value opt.lif_beta=0.7, the time constant is 2.8 steps
# /Users/laurentperrinet/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages/snntorch/spikeplot.py:120: UserWarning: You passed a edgecolor/edgecolors ('none') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   return ax.scatter(*torch.where(data.cpu()), **kwargs)
# Target pattern generated with shape torch.Size([2, 128, 125]) and mean 1.563e-04
# Flipping 342.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 1.084e-02
# Flipping 298.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 9.469e-03
# Flipping 330.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 1.047e-02
# Flipping 314.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 9.906e-03
# Spikes in one target 2.6,  in a SM window 0.8
# for a value opt.lif_beta=0.7, the time constant is 2.8 steps
# Model file not found: ../cached_data/2026-06-18_init.pth, intitializing the new model.
# precision = 0.000	 recall = 0.000	 f1_score = 0.000
# Model file not found: ../cached_data/2026-06-18_vanilla.pth, training a new model.
# Train Epoch [000001/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000002/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000003/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000004/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000005/000032]	| Loss = 1.000e+00	| precision = 0.000	| recall = 0.000	| f1_score = 0.000	|
# Train Epoch [000006/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000007/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000008/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000009/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000010/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000011/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000012/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000013/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000014/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000015/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000016/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000017/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000018/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000019/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000020/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000021/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000022/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000023/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000024/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000025/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000026/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000027/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000028/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000029/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000030/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000031/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# Train Epoch [000032/000032]	| Loss = 5.000e-01	| precision = 1.000	| recall = 0.333	| f1_score = 0.500	|
# precision = 1.000	 recall = 0.333	 f1_score = 0.500
# ✅ END: 2026-06-20 09:24:00

# %%
pprint("🚀 Running: 20_MNESIS_scanning-parameters.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 20_MNESIS_scanning-parameters.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ==============================================
# 🚀 Running: 20_MNESIS_scanning-parameters.ipynb
# ==============================================
# ⏱️  START: 2026-06-20 09:24:00
# datetag = '2026-06-18'
# Using device: mps
# SNNtorch version 0.9.4
# Spikes in one target 2.6,  in a SM window 0.8
# for a value opt.lif_beta=0.7, the time constant is 2.8 steps
# /Users/laurentperrinet/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages/snntorch/spikeplot.py:120: UserWarning: You passed a edgecolor/edgecolors ('none') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   return ax.scatter(*torch.where(data.cpu()), **kwargs)
# Target pattern generated with shape torch.Size([2, 128, 125]) and mean 1.563e-04
# Flipping 342.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 1.084e-02
# Flipping 298.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 9.469e-03
# Flipping 330.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 1.047e-02
# Flipping 314.0 bits out of 32000 (p_flip=0.01), 1.563e-04 -> 9.906e-03
# Spikes in one target 2.6,  in a SM window 0.8
# for a value opt.lif_beta=0.7, the time constant is 2.8 steps
# ================================================================================
# Scanning core network parameters to evaluate learning performance and robustness
# ================================================================================
# --------------------------------------------------
# scanning key='N_pattern'
# --------------------------------------------------
# --------------------------------------------------
# scanning key='N_time'
# --------------------------------------------------
# | 1 / 1	|key='N_time':value=1.000e+02 	| loss=1.000	| completed in 1.0m 8.3s |
# |key='N_time':value=1.000e+02 	| loss=1.000	| completed in 1.0m 8.5s |
# |key='N_time':value=1.000e+02 	| already computed for i_cv=1, skipping.	| completed in 1.0m 8.5s |
# |key='N_time':value=1.000e+02 	| loss=1.000	| completed in 1.0m 3.0s |

# %%
pprint("🚀 Running: 13_MNESIS_testing-inference.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 13_MNESIS_testing-inference.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 14_MNESIS_testing-noise.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 14_MNESIS_testing-noise.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 15_MNESIS_testing-trigger-duration.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 15_MNESIS_testing-trigger-duration.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 16_MNESIS_testing-trigger-fraction.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 16_MNESIS_testing-trigger-fraction.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 25_MNESIS_optuna.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 25_MNESIS_optuna.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 30_MNESIS_learn-periodic.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 30_MNESIS_learn-periodic.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 32_MNESIS_learn-travelling-waves.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 32_MNESIS_learn-travelling-waves.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 34_MNESIS_learn-Lorenz-attractor.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 34_MNESIS_learn-Lorenz-attractor.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# pprint("🚀 Running: 40_MNESIS_learn-SHD.ipynb")
# print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 40_MNESIS_learn-SHD.ipynb
# print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("✅ All MNESIS notebooks executed successfully!")
