# %% [markdown]
# # MNESIS : a notebook that runs all of them

# %%
# %pip install -U -r requirements.txt

# %%
from mnesis_boilerplate import datetime
from mnesis_boilerplate import pprint
# Out:
# datetag = '2026-09-07'
# Using device: mps

# %%
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
pprint("🚀 Importing: mnesis_boilerplate.py")
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ⏱️  START: 2026-09-21 09:36:27
# ==================================
# 🚀 Importing: mnesis_boilerplate.py
# ==================================
# ✅ END: 2026-09-21 09:36:27

# %%
pprint("🚀 Running: 10_MNESIS_generative-model.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 10_MNESIS_generative-model.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ===========================================
# 🚀 Running: 10_MNESIS_generative-model.ipynb
# ===========================================
# ⏱️  START: 2026-09-21 09:36:27
# File ../figures/ssp_frozen_pattern.pdf already exists. Skipping save.
# File ../figures/ssp_frozen_pattern.png already exists. Skipping save.
# File ../figures/ssp_frozen_pattern.svg already exists. Skipping save.
# /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages/snntorch/spikeplot.py:120: UserWarning: You passed an edgecolor/edgecolors ('none') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   return ax.scatter(*torch.where(data.cpu()), **kwargs)
# Description: Stochastic spike pattern generator
# Target pattern generated with shape torch.Size([16, 1024, 1000]) and mean 1.579e-04
# Target pattern generated with shape torch.Size([16, 1024, 1000]) and mean 1.579e-04
# Flipping 1637471.0 bits out of 16384000 (p_flip=0.1, flip seed=15648272732876554160), 1.579e-04 -> 1.001e-01
# Flipping 1638307.0 bits out of 16384000 (p_flip=0.1, flip seed=6030125426509996519), 1.579e-04 -> 1.001e-01
# File ../figures/ssp_two_frozen_pattern.pdf already exists. Skipping save.
# File ../figures/ssp_two_frozen_pattern.png already exists. Skipping save.
# File ../figures/ssp_two_frozen_pattern.svg already exists. Skipping save.
# /Users/laurent/sdrive_cnrs/hot_from_git/TemporallyHeterogeneousConnections/MNESIS/.venv/lib/python3.12/site-packages/snntorch/spikeplot.py:120: UserWarning: You passed an edgecolor/edgecolors ('none') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   return ax.scatter(*torch.where(data.cpu()), **kwargs)
# ✅ END: 2026-09-21 09:36:28

# %%
pprint("🚀 Running: 11_MNESIS_learn-synthetic.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 11_MNESIS_learn-synthetic.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ==========================================
# 🚀 Running: 11_MNESIS_learn-synthetic.ipynb
# ==========================================
# ⏱️  START: 2026-09-21 09:36:28
# Spikes in one target 163.8,  in a SM window 6.7
# for a value opt.lif_beta=0.7, the time constant is 2.8 steps
# Model weights loaded from ../cached_data/2026-09-07_init.pth
# precision = 0.894	 recall = 0.746	 f1_score = 0.813
# File ../figures/pattern.pdf already exists. Skipping save.
# File ../figures/pattern.png already exists. Skipping save.
# File ../figures/pattern.svg already exists. Skipping save.
# File ../figures/target_init.pdf already exists. Skipping save.
# File ../figures/target_init.png already exists. Skipping save.
# File ../figures/target_init.svg already exists. Skipping save.
# Model weights loaded from ../cached_data/2026-09-07_vanilla.pth
# precision = 0.894	 recall = 0.746	 f1_score = 0.813
# File ../figures/target.pdf already exists. Skipping save.
# File ../figures/target.png already exists. Skipping save.
# File ../figures/target.svg already exists. Skipping save.
# File ../figures/histogram_log.pdf already exists. Skipping save.
# File ../figures/histogram_log.png already exists. Skipping save.
# File ../figures/histogram_log.svg already exists. Skipping save.
# ✅ END: 2026-09-21 09:36:33

# %%
pprint("🚀 Running: 13_MNESIS_testing-inference.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 13_MNESIS_testing-inference.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ============================================
# 🚀 Running: 13_MNESIS_testing-inference.ipynb
# ============================================
# ⏱️  START: 2026-09-21 09:36:33
# Model weights loaded from ../cached_data/2026-09-07_vanilla.pth
# Model weights loaded from ../cached_data/2026-09-07_vanilla.pth - the pattern generator is the Stochastic spike pattern generator
# Score weights loaded from ../cached_data/2026-09-07_score.npy
# File ../figures/retrieval.pdf already exists. Skipping save.
# File ../figures/retrieval.png already exists. Skipping save.
# File ../figures/retrieval.svg already exists. Skipping save.
# /var/folders/qt/n82pbkv93fjb7bpt0pj1992w0000gn/T/ipykernel_23506/220220000.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc='lower right')
# ✅ END: 2026-09-21 09:36:34

# %%
pprint("🚀 Running: 14_MNESIS_testing-noise.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 14_MNESIS_testing-noise.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ========================================
# 🚀 Running: 14_MNESIS_testing-noise.ipynb
# ========================================
# ⏱️  START: 2026-09-21 09:36:34
# Model weights loaded from ../cached_data/2026-09-07_vanilla.pth
# Model weights loaded from ../cached_data/2026-09-07_vanilla.pth
# precision = 0.680	 recall = 0.448	 f1_score = 0.540
# File ../figures/p_flip_target.pdf already exists. Skipping save.
# File ../figures/p_flip_target.png already exists. Skipping save.
# File ../figures/p_flip_target.svg already exists. Skipping save.
# Score weights loaded from ../cached_data/2026-09-07_noise.npz
# File ../figures/p_flip_score.pdf already exists. Skipping save.
# File ../figures/p_flip_score.png already exists. Skipping save.
# File ../figures/p_flip_score.svg already exists. Skipping save.
# Score file is locked: ../cached_data/2026-09-07_noise_retrain.lock, passing.
# Retrain score file not available yet: ../cached_data/2026-09-07_noise_retrain.npz (locked or not computed).
# ✅ END: 2026-09-21 09:36:37

# %%
pprint("🚀 Running: 15_MNESIS_testing-trigger-duration.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 15_MNESIS_testing-trigger-duration.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ===================================================
# 🚀 Running: 15_MNESIS_testing-trigger-duration.ipynb
# ===================================================
# ⏱️  START: 2026-09-21 09:36:37
# Model weights loaded from ../cached_data/2026-09-07_vanilla.pth
# precision = 0.819	 recall = 0.506	 f1_score = 0.626
# File ../figures/trigger_time.pdf already exists. Skipping save.
# File ../figures/trigger_time.png already exists. Skipping save.
# File ../figures/trigger_time.svg already exists. Skipping save.
# Score weights loaded from ../cached_data/2026-09-07_trigger_time.npz
# File ../figures/trigger_time_score.pdf already exists. Skipping save.
# File ../figures/trigger_time_score.png already exists. Skipping save.
# File ../figures/trigger_time_score.svg already exists. Skipping save.
# ✅ END: 2026-09-21 09:36:39

# %%
pprint("🚀 Running: 16_MNESIS_testing-trigger-fraction.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 16_MNESIS_testing-trigger-fraction.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ===================================================
# 🚀 Running: 16_MNESIS_testing-trigger-fraction.ipynb
# ===================================================
# ⏱️  START: 2026-09-21 09:36:39
# Model weights loaded from ../cached_data/2026-09-07_vanilla.pth
# precision = 0.893	 recall = 0.743	 f1_score = 0.811
# File ../figures/fraction_target.pdf already exists. Skipping save.
# File ../figures/fraction_target.png already exists. Skipping save.
# File ../figures/fraction_target.svg already exists. Skipping save.
# Score weights loaded from ../cached_data/2026-09-07_N_neurons.npz
# File ../figures/fraction_target_score.pdf already exists. Skipping save.
# File ../figures/fraction_target_score.png already exists. Skipping save.
# File ../figures/fraction_target_score.svg already exists. Skipping save.
# ✅ END: 2026-09-21 09:36:42

# %%
pprint("🚀 Running: 20_MNESIS_scanning-parameters.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 20_MNESIS_scanning-parameters.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ==============================================
# 🚀 Running: 20_MNESIS_scanning-parameters.ipynb
# ==============================================
# ⏱️  START: 2026-09-21 09:36:42
# Spikes in one target 163.8,  in a SM window 6.7
# for a value opt.lif_beta=0.7, the time constant is 2.8 steps
# ================================================================================
# Scanning core network parameters to evaluate learning performance and robustness
# ================================================================================
# --------------------------------------------------
# scanning key='N_pattern'
# --------------------------------------------------
# --------------------------------------------------
# scanning key='N_time'
# --------------------------------------------------
# --------------------------------------------------
# scanning key='num_delay'
# --------------------------------------------------
# --------------------------------------------------
# scanning key='N_neuron'
# --------------------------------------------------
# --------------------------------------------------
# scanning key='p_A'
# --------------------------------------------------
# --------------------------------------------------
# scanning key='lif_threshold'
# --------------------------------------------------
# --------------------------------------------------
# scanning key='do_deconv'
# --------------------------------------------------
# --------------------------------------------------
# scanning key='do_pinv'
# --------------------------------------------------
# --------------------------------------------------
# scanning key='p_flip'
# --------------------------------------------------
# --------------------------------------------------
# scanning key='N_pattern'
# --------------------------------------------------
# --------------------------------------------------
# scanning key='N_time'
# --------------------------------------------------
# --------------------------------------------------
# scanning key='num_delay'
# --------------------------------------------------
# --------------------------------------------------
# scanning key='N_neuron'
# --------------------------------------------------
# --------------------------------------------------
# scanning key='p_A'
# --------------------------------------------------
# --------------------------------------------------
# scanning key='lif_threshold'
# --------------------------------------------------
# --------------------------------------------------
# scanning key='do_deconv'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-09-07_scan_do_deconv.json')...
#     do_deconv  i_cv      loss         time  f1-score
# 0        True     0  0.111824  3098.348683  0.888176
# 1        True     1  0.214923  2759.693664  0.785077
# 2        True     2  0.106265  2871.034452  0.893735
# 3        True     3  0.058313  2921.667443  0.941687
# 4        True     4  0.117301  2899.598389  0.882699
# 5        True     5  0.184100  2920.362912  0.815900
# 6        True     6  0.142002  2857.802707  0.857998
# 7        True     7  0.148784  2968.103649  0.851216
# 8        True     8  0.078633  2906.092801  0.921367
# 9        True     9  0.128732  2764.556605  0.871268
# 10      False     5  0.123859  3016.618532  0.876141
# 11      False     9  0.104434  2877.888148  0.895566
# 12      False     7  0.106655  2766.973186  0.893345
# 13      False     8  0.060663  2694.985537  0.939337
# 14      False     6  0.085774  2759.800642  0.914226
# 15      False     2  0.125445  2820.912995  0.874555
# 16      False     1  0.139565  2711.596067  0.860435
# 17      False     4  0.142224  2688.597761  0.857776
# 18      False     0  0.062591  2838.876791  0.937409
# 19      False     3  0.148835  3097.724577  0.851165
# File ../figures/scan_do_deconv.pdf already exists. Skipping save.
# File ../figures/scan_do_deconv.png already exists. Skipping save.
# File ../figures/scan_do_deconv.svg already exists. Skipping save.
# --------------------------------------------------
# scanning key='do_pinv'
# --------------------------------------------------
# Reading filename=PosixPath('../cached_data/2026-09-07_scan_do_pinv.json')...
#     do_pinv  i_cv      loss         time  f1-score
# 0      True     0  0.096774  2959.673100  0.903226
# 1      True     1  0.182021  3043.904157  0.817979
# 2      True     2  0.126010  2997.662065  0.873990
# 3      True     3  0.042647  2955.444406  0.957353
# 4      True     4  0.050122  2736.148267  0.949878
# 5      True     5  0.116070  2778.615113  0.883930
# 6      True     6  0.177019  2717.103452  0.822981
# 7      True     7  0.099277  2761.778470  0.900723
# 8      True     8  0.109963  2731.502217  0.890037
# 9      True     9  0.146677  2719.097740  0.853323
# 10    False     5  0.998708  1769.943036  0.001292
# 11    False     9  0.998742  1755.429639  0.001258
# 12    False     7  0.998642  1786.239497  0.001358
# 13    False     8  0.998573  1766.437789  0.001427
# 14    False     6  0.998682  1760.650421  0.001318
# 15    False     2  0.998864  1743.964508  0.001136
# 16    False     1  0.998956  1732.055007  0.001044
# 17    False     4  0.998593  1730.423062  0.001407
# 18    False     0  0.998254  1720.050741  0.001746
# 19    False     3  0.999178  1697.716879  0.000822
# File ../figures/scan_do_pinv.pdf already exists. Skipping save.
# File ../figures/scan_do_pinv.png already exists. Skipping save.
# File ../figures/scan_do_pinv.svg already exists. Skipping save.
# --------------------------------------------------
# scanning key='p_flip'
# --------------------------------------------------
# ✅ END: 2026-09-21 09:36:42

# %%
pprint("🚀 Running: 25_MNESIS_optuna.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 25_MNESIS_optuna.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# =================================
# 🚀 Running: 25_MNESIS_optuna.ipynb
# =================================
# ⏱️  START: 2026-09-21 09:36:42
# ===================================================================================================
# Optimizing learning parameters with Optuna: running hyperparameter search and analyzing best trials
# ===================================================================================================
# -rw-r-----@ 1 laurent  staff  221184 21 sept. 09:36 ../cached_data/2026-09-07_optuna.sqlite3
# Optuna file is locked: ../cached_data/2026-09-07_optuna.lock, passing.
# Study is None (likely due to lock), skipping load.
# Study is None, skipping trials display.
# Study is None, skipping best-trial summary.
# Study is None, skipping parameter-importance plot.
# Study is None, skipping diagnostic plots.
# ✅ END: 2026-09-21 09:36:43

# %%
pprint("🚀 Running: 30_MNESIS_learn-periodic.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 30_MNESIS_learn-periodic.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# =========================================
# 🚀 Running: 30_MNESIS_learn-periodic.ipynb
# =========================================
# ⏱️  START: 2026-09-21 09:36:43
# Model weights loaded from ../cached_data/2026-09-07_periodic.pth
# precision = 0.940	 recall = 0.827	 f1_score = 0.880
# Model weights loaded from ../cached_data/2026-09-07_periodic_spikes.pth
# precision = 0.933	 recall = 0.827	 f1_score = 0.876
# Spike file not found: ../cached_data/2026-09-07_periodic_spikes_noisy.pth, running the model.
# precision = 1.000	 recall = 0.827	 f1_score = 0.905
# Score weights loaded from ../cached_data/2026-09-07_periodic-with-noise.npz
# ✅ END: 2026-09-21 09:37:48

# %%
pprint("🚀 Running: 32_MNESIS_learn-travelling-waves.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 32_MNESIS_learn-travelling-waves.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# =================================================
# 🚀 Running: 32_MNESIS_learn-travelling-waves.ipynb
# =================================================
# ⏱️  START: 2026-09-21 09:37:48
# =========================================================================
# Defining traveling wave patterns and building the spike-pattern generator
# =========================================================================
# File ../figures/TW_image.pdf already exists. Skipping save.
# File ../figures/TW_image.png already exists. Skipping save.
# File ../figures/TW_image.svg already exists. Skipping save.
# ======================================================
# Learning traveling wave patterns with the HD_SNN model
# ======================================================
# Model file not found: ../cached_data/2026-09-07_TW_weights.pth, inititializing and learning the new model.

# %%
pprint("🚀 Running: 34_MNESIS_learn-Lorenz-attractor.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 34_MNESIS_learn-Lorenz-attractor.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("🚀 Running: 36_MNESIS_learn-text.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 36_MNESIS_learn-text.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# pprint("🚀 Running: 40_MNESIS_learn-SHD.ipynb")
# print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 40_MNESIS_learn-SHD.ipynb
# print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
pprint("✅ All MNESIS notebooks executed successfully!")
