# %% [markdown]
# # MNESIS : a notebook that runs all of them

# %% [markdown]
# ## Run all notebooks in numerical order (simple to complex)

# %%
import datetime
print("🚀 Running: 01_MNESIS_boilerplate.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 01_MNESIS_boilerplate.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
print("🚀 Running: 05_MNESIS_parameters.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 05_MNESIS_parameters.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
print("🚀 Running: 08_MNESIS_generative-model.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 08_MNESIS_generative-model.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
print("🚀 Running: 10_MNESIS_polychronous-chains.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 10_MNESIS_polychronous-chains.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
print("🚀 Running: 11_MNESIS_learn-synthetic.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 11_MNESIS_learn-synthetic.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
print("🚀 Running: 13_MNESIS_testing-inference.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 13_MNESIS_testing-inference.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
print("🚀 Running: 14_MNESIS_testing-noise.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 14_MNESIS_testing-noise.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
print("🚀 Running: 15_MNESIS_testing-trigger-duration.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 15_MNESIS_testing-trigger-duration.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
print("🚀 Running: 16_MNESIS_testing-trigger-fraction.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 16_MNESIS_testing-trigger-fraction.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
print("🚀 Running: 20_MNESIS_scanning-parameters.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 20_MNESIS_scanning-parameters.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
print("🚀 Running: 25_MNESIS_optuna.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 25_MNESIS_optuna.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
print("🚀 Running: 30_MNESIS_learn-periodic.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 30_MNESIS_learn-periodic.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
print("🚀 Running: 32_MNESIS_learn-travelling-waves.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 32_MNESIS_learn-travelling-waves.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
print("🚀 Running: 34_MNESIS_learn-Lorenz-attractor.ipynb")
print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 34_MNESIS_learn-Lorenz-attractor.ipynb
print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# print("🚀 Running: 40_MNESIS_learn-SHD.ipynb")
# print(f"⏱️  START: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# %run 40_MNESIS_learn-SHD.ipynb
# print(f"✅ END: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
print("✅ All MNESIS notebooks executed successfully!")
